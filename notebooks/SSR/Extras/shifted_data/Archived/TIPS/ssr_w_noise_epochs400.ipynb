# %%
# %load_ext cuml.accel
# %run /workspace/alvin/SAR_ML/notebooks/SSR/SSRtransforms_preloaded.py
# %run /mnt/d/Users/Admin/Projects/dso/SAR_ML/notebooks/SSR/SSRtransforms_preloaded.py
import os
import re
import copy
import random
from collections import defaultdict
from joblib import Parallel, delayed
from tqdm import tqdm
import pickle
import time

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from cuml.manifold import TSNE, UMAP

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms, models
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, ConcatDataset, Subset, Dataset

import sys
sys.path.append("/mnt/d/Users/Admin/Projects/dso/SAR_ML/notebooks/SSR/Extras/TIPS")
from tips import TIPS
from tips_resnet18 import TIPSResNet18, tips_regularization_loss

# %%
def set_seed(seed=42):
    """Set all random seeds for reproducibility"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    # Uncomment only if you need 100% determinism and can handle errors
    # torch.use_deterministic_algorithms(True, warn_only=True)
    # os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
    
    os.environ["PYTHONHASHSEED"] = str(seed)

def worker_init_fn(worker_id):
    """DataLoader worker init for reproducibility"""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %%
# workspace = "/workspace/alvin/SAR_ML"
workspace = "/mnt/d/Users/Admin/Projects/dso/SAR_ML"
data_workspace = os.path.join(workspace, "data/SAMPLE")

# %%
with open(os.path.join(workspace, "weights/SSR/SAMPLE_synth_gmm_cache.pkl"), "rb") as f:
    gmm_cache = pickle.load(f)

# %%
no_aug_synth_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/synth"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), LogMapping(c = 1000.0), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)

SSR_synth_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/synth"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), LogMapping(c = 1000.0), SSRAugmentation(gmm_cache, alpha=0.6, beta=0.4, apply_prob=0.5, gaussian_noise = True, mu_s = 0.0, sigma_s = 0.3), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)

meas_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/real"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), LogMapping(c = 1000.0), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)

# %%
train_ds = filter_by_elev(SSR_synth_ds, {14, 15, 16})
valid_ds = filter_by_elev(meas_ds, {14, 15, 16})
test_ds = filter_by_elev(meas_ds, {17})

ds_dict = {"train" : train_ds, "val": valid_ds, "test": test_ds}
dataset_sizes = {"train" : len(train_ds), "val": len(valid_ds), "test": len(test_ds)}

# %%
model = TIPSResNet18(num_classes=len(train_ds.class_to_idx), pad_type='reflect')

tips_param_names = {
    f"{mod_name}.{p_name}"
    for mod_name, module in model.named_modules()
    if isinstance(module, TIPS)
    for p_name, _ in module.named_parameters()
}
pool_param_count = sum(
    p.numel() for n, p in model.named_parameters() if n in tips_param_names
)
total_param_count = sum(p.numel() for p in model.parameters())
print(f"{pool_param_count} ({100*pool_param_count/total_param_count:.2f}% of total)")

frozen = [n for n, p in model.named_parameters() if not p.requires_grad]
print(frozen)  # should be []

# sanity: confirm this is actually finding all 7 TIPS layers
tips_module_names = [n for n, m in model.named_modules() if isinstance(m, TIPS)]
print(f"{len(tips_module_names)} TIPS layers:", tips_module_names)
# Out:
# 14080 (0.13% of total)
# []
# 7 TIPS layers: ['core.stem_pool', 'core.layer2.0.downsample', 'core.layer2.0.shortcut_tips', 'core.layer3.0.downsample', 'core.layer3.0.shortcut_tips', 'core.layer4.0.downsample', 'core.layer4.0.shortcut_tips']

# %%
# seed_lst = [10, 42, 100, 123, 666, 777, 849, 1000, 1111, 1234]
seed_lst = [10]
 
train_loss = []
val_loss = []
train_acc = []
val_acc = []

num_epochs = 400
alpha = 0.35
epilson = 0.4

wake_up_epoch = int(epilson * num_epochs)

TRACK_LAYERS = {0: "stem", 5: "layer4.downsample"}

running_tau_norm = {name: 0.0 for name in TRACK_LAYERS.values()}

for i, seed in enumerate(seed_lst):
    
    start = time.perf_counter()
    
    print(f"Training Run {i}: seed {seed}")
    set_seed(seed)
 
    dataloaders = {
        "train": DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=8, pin_memory=True, persistent_workers=True, prefetch_factor=4, worker_init_fn=worker_init_fn, generator=torch.Generator().manual_seed(seed)),
        "val": DataLoader(valid_ds, batch_size=16, shuffle=False, num_workers=8, pin_memory=True, persistent_workers=True, prefetch_factor=4, worker_init_fn=worker_init_fn, generator=torch.Generator().manual_seed(seed)),
        "test": DataLoader(test_ds, batch_size=16, shuffle=False, num_workers=8, pin_memory=True, persistent_workers=True, prefetch_factor=4, worker_init_fn=worker_init_fn, generator=torch.Generator().manual_seed(seed))
    }
 
    # --- CHANGED: TIPSResNet18 instead of LPDResNet18 ---
    # Dropout head is built in (dropout_p=0.4 default), same convention as LPDResNet18.
    model = TIPSResNet18(num_classes=len(train_ds.class_to_idx), pad_type="reflect")
 
    # Define the loss function and optimizer
    criterion = nn.CrossEntropyLoss()
 
    # --- CHANGED (vs LPD): single param group, no weight_decay=0 split.
    # LPD's split existed because LPS does *hard* phase selection and
    # weight decay directly fights that. TIPS's tau is a soft mixture
    # regularized by L_FM instead (Eq. 3) -- the mechanism LPD protected
    # via weight_decay=0 is handled here by a loss term, not an
    # optimizer setting. If TIPS's dw_conv/mix_conv params turn out to
    # need the same protection empirically, split them out the same way:
    #   if "downsample" in n or "shortcut_tips" in n or "stem_pool" in n
    optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=2e-4)
 
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=3e-7)
 
    # move model to GPU
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
 
    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": []
    }
 
    # Training loop
    for epoch in range(num_epochs):
        print(f"Epoch {epoch}")
        if epoch == 0:
            # --- CHANGED: conv1 now lives under model.core.conv1,
            # since LPDResNet18 wraps a torchvision ResNet as self.core
            print(f"First layer mean: {model.core.conv1.weight.data.mean():.6f}")
        for phase in ["train", "val"]:
            if phase == "train":
                model.train()
            else:
                model.eval()
 
            running_loss = 0.0
            running_corrects = 0
            running_reg_loss = 0.0
 
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
 
                optimizer.zero_grad()
 
                with torch.set_grad_enabled(phase == "train"):
                    # --- CHANGED: TIPSResNet18 always returns (logits, aux)
                    outputs, aux = model(inputs)
                    if phase == "train":
                        with torch.no_grad():
                            for idx, name in TRACK_LAYERS.items():
                                tau_norm = aux[idx]["tau"].norm(dim = -1).mean().item()
                                running_tau_norm[name] += tau_norm * inputs.size(0)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
 
                    if phase == "train":
                        # --- CHANGED: add TIPS regularization only during
                        # training, matching how LPD's loss was plain
                        # criterion() in both phases (val loss stays a
                        # clean task-loss number for comparability, no
                        # regularization term baked in)
                        reg_loss = tips_regularization_loss(aux, epoch, wake_up_epoch, alpha=alpha)
                        total_loss = (1 - alpha) * loss + reg_loss
                        total_loss.backward()
                        optimizer.step()
                        running_reg_loss += reg_loss.item() * inputs.size(0)
 
                running_loss += loss.item() * inputs.size(0)
                running_corrects += (preds == labels).sum().item()
 
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]
 
            history[f"{phase}_loss"].append(epoch_loss)
            history[f"{phase}_acc"].append(epoch_acc)

            if phase == "train":
                epoch_reg_loss = running_reg_loss / dataset_sizes[phase]
                tau_str = " ".join(f"{name} = {running_tau_norm[name]/dataset_sizes[phase]:.4f}" for name in TRACK_LAYERS.values())
                
                print(f"{phase} Loss: {epoch_loss:.10f} Acc: {epoch_acc:.10f} RegLoss: {epoch_reg_loss:.10f} ||tau||: {tau_str}")
                running_tau_norm = {name: 0.0 for name in TRACK_LAYERS.values()}
            else:
                print(f"{phase} Loss: {epoch_loss:.10f} Acc: {epoch_acc:.10f}")
 
        scheduler.step()
        print(f"Epoch {epoch} LR: {scheduler.get_last_lr()[0]:.10f}")
 
    print("Training complete!")
 
    train_loss.append(history["train_loss"])
    val_loss.append(history["val_loss"])
    train_acc.append(history["train_acc"])
    val_acc.append(history["val_acc"])
 
    torch.save(model.state_dict(), os.path.join(workspace, f"weights/SSR/Extras/TIPS/SSR_w_noise/rn18_seed{seed}_b16_epochs{num_epochs}.pth"))
    end = time.perf_counter()
    elapsed = end - start
    print(f"Training time for Seed {seed}: {elapsed:.2f}s")
 
train_loss = np.array(train_loss)
val_loss = np.array(val_loss)
train_acc = np.array(train_acc)
val_acc = np.array(val_acc)
# Out:
# Training Run 0: seed 10
# Epoch 0
# First layer mean: -0.000287
# train Loss: 2.2978427457 Acc: 0.1873449132 RegLoss: -1.5000008762 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.4618451193 Acc: 0.1439205955
# Epoch 0 LR: 0.0002999954
# Epoch 1
# train Loss: 2.1056774899 Acc: 0.2059553350 RegLoss: -1.5000011702 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.1018894967 Acc: 0.2506203474
# Epoch 1 LR: 0.0002999815
# Epoch 2
# train Loss: 2.0202764595 Acc: 0.2307692308 RegLoss: -1.5000015062 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.2024373177 Acc: 0.1588089330
# Epoch 2 LR: 0.0002999584
# Epoch 3
# train Loss: 1.8895101476 Acc: 0.2655086849 RegLoss: -1.5000017852 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.2215220922 Acc: 0.1724565757
# Epoch 3 LR: 0.0002999261
# Epoch 4
# train Loss: 1.7641406808 Acc: 0.3250620347 RegLoss: -1.5000021975 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.9514442546 Acc: 0.3014888337
# Epoch 4 LR: 0.0002998845
# Epoch 5
# train Loss: 1.6207202244 Acc: 0.3784119107 RegLoss: -1.5000025904 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 4.3275835020 Acc: 0.1761786600
# Epoch 5 LR: 0.0002998336
# Epoch 6
# train Loss: 1.4310764474 Acc: 0.4218362283 RegLoss: -1.5000036488 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.0776843233 Acc: 0.2853598015
# Epoch 6 LR: 0.0002997736
# Epoch 7
# train Loss: 1.1548661408 Acc: 0.5657568238 RegLoss: -1.5000048950 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.0317306075 Acc: 0.2803970223
# Epoch 7 LR: 0.0002997043
# Epoch 8
# train Loss: 0.9388900176 Acc: 0.6724565757 RegLoss: -1.5000063409 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 3.5761212633 Acc: 0.3821339950
# Epoch 8 LR: 0.0002996258
# Epoch 9
# train Loss: 0.6638760076 Acc: 0.7531017370 RegLoss: -1.5000087135 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.2025012857 Acc: 0.5781637717
# Epoch 9 LR: 0.0002995381
# Epoch 10
# train Loss: 0.4926315213 Acc: 0.8424317618 RegLoss: -1.5000084568 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.3559356400 Acc: 0.3287841191
# Epoch 10 LR: 0.0002994411
# Epoch 11
# train Loss: 0.4425254026 Acc: 0.8622828784 RegLoss: -1.5000102449 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.2619734568 Acc: 0.6799007444
# Epoch 11 LR: 0.0002993350
# Epoch 12
# train Loss: 0.2861301194 Acc: 0.9230769231 RegLoss: -1.5000100875 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.1168887911 Acc: 0.6290322581
# Epoch 12 LR: 0.0002992196
# Epoch 13
# train Loss: 0.2239572790 Acc: 0.9404466501 RegLoss: -1.5000109900 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 3.9293884789 Acc: 0.3424317618
# Epoch 13 LR: 0.0002990950
# Epoch 14
# train Loss: 0.1818319996 Acc: 0.9516129032 RegLoss: -1.5000121617 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.3208022480 Acc: 0.4416873449
# Epoch 14 LR: 0.0002989613
# Epoch 15
# train Loss: 0.2471416811 Acc: 0.9255583127 RegLoss: -1.5000121315 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.2093435592 Acc: 0.4900744417
# Epoch 15 LR: 0.0002988184
# Epoch 16
# train Loss: 0.1700198739 Acc: 0.9565756824 RegLoss: -1.5000141918 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.1922868906 Acc: 0.5893300248
# Epoch 16 LR: 0.0002986663
# Epoch 17
# train Loss: 0.1377082941 Acc: 0.9652605459 RegLoss: -1.5000141093 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.6021090891 Acc: 0.5372208437
# Epoch 17 LR: 0.0002985050
# Epoch 18
# train Loss: 0.1201249464 Acc: 0.9627791563 RegLoss: -1.5000155614 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.6720405191 Acc: 0.5645161290
# Epoch 18 LR: 0.0002983346
# Epoch 19
# train Loss: 0.1100807871 Acc: 0.9714640199 RegLoss: -1.5000181379 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.1419723806 Acc: 0.6327543424
# Epoch 19 LR: 0.0002981551
# Epoch 20
# train Loss: 0.0932017321 Acc: 0.9739454094 RegLoss: -1.5000201260 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.7292512433 Acc: 0.7940446650
# Epoch 20 LR: 0.0002979664
# Epoch 21
# train Loss: 0.0693459371 Acc: 0.9863523573 RegLoss: -1.5000229003 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.9163060464 Acc: 0.6885856079
# Epoch 21 LR: 0.0002977686
# Epoch 22
# train Loss: 0.1168084220 Acc: 0.9615384615 RegLoss: -1.5000268573 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.8860896808 Acc: 0.3436724566
# Epoch 22 LR: 0.0002975617
# Epoch 23
# train Loss: 0.0862935764 Acc: 0.9751861042 RegLoss: -1.5000305939 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.6222875870 Acc: 0.6253101737
# Epoch 23 LR: 0.0002973457
# Epoch 24
# train Loss: 0.0814847862 Acc: 0.9764267990 RegLoss: -1.5000362343 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.9501131406 Acc: 0.6724565757
# Epoch 24 LR: 0.0002971207
# Epoch 25
# train Loss: 0.0803783123 Acc: 0.9751861042 RegLoss: -1.5000389832 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.0958749471 Acc: 0.7295285360
# Epoch 25 LR: 0.0002968865
# Epoch 26
# train Loss: 0.0657401688 Acc: 0.9776674938 RegLoss: -1.5000447768 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.2338079609 Acc: 0.7009925558
# Epoch 26 LR: 0.0002966434
# Epoch 27
# train Loss: 0.1103740560 Acc: 0.9665012407 RegLoss: -1.5000561073 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 3.1499580739 Acc: 0.4826302730
# Epoch 27 LR: 0.0002963911
# Epoch 28
# train Loss: 0.0863766510 Acc: 0.9751861042 RegLoss: -1.5000707015 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.9797601862 Acc: 0.6873449132
# Epoch 28 LR: 0.0002961299
# Epoch 29
# train Loss: 0.0598925180 Acc: 0.9813895782 RegLoss: -1.5000782185 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.6284497899 Acc: 0.8052109181
# Epoch 29 LR: 0.0002958596
# Epoch 30
# train Loss: 0.0638290221 Acc: 0.9826302730 RegLoss: -1.5000886169 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.4459813316 Acc: 0.6625310174
# Epoch 30 LR: 0.0002955804
# Epoch 31
# train Loss: 0.0909316757 Acc: 0.9801488834 RegLoss: -1.5001162172 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.7348079703 Acc: 0.7903225806
# Epoch 31 LR: 0.0002952922
# Epoch 32
# train Loss: 0.0518932967 Acc: 0.9851116625 RegLoss: -1.5001497973 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.9297509886 Acc: 0.7344913151
# Epoch 32 LR: 0.0002949950
# Epoch 33
# train Loss: 0.0523247973 Acc: 0.9813895782 RegLoss: -1.5001975251 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.1232556183 Acc: 0.7295285360
# Epoch 33 LR: 0.0002946889
# Epoch 34
# train Loss: 0.0592428804 Acc: 0.9813895782 RegLoss: -1.5002277690 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.6750885634 Acc: 0.7977667494
# Epoch 34 LR: 0.0002943739
# Epoch 35
# train Loss: 0.0519300325 Acc: 0.9838709677 RegLoss: -1.5002802900 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.1226776812 Acc: 0.6923076923
# Epoch 35 LR: 0.0002940500
# Epoch 36
# train Loss: 0.0391609063 Acc: 0.9888337469 RegLoss: -1.5003418360 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.9730123180 Acc: 0.7282878412
# Epoch 36 LR: 0.0002937172
# Epoch 37
# train Loss: 0.0654950648 Acc: 0.9813895782 RegLoss: -1.5004689750 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.9588642969 Acc: 0.6960297767
# Epoch 37 LR: 0.0002933756
# Epoch 38
# train Loss: 0.0482253542 Acc: 0.9863523573 RegLoss: -1.5006112585 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.4285749570 Acc: 0.8622828784
# Epoch 38 LR: 0.0002930251
# Epoch 39
# train Loss: 0.0559810502 Acc: 0.9900744417 RegLoss: -1.5007710055 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.8430102360 Acc: 0.8014888337
# Epoch 39 LR: 0.0002926658
# Epoch 40
# train Loss: 0.0227659684 Acc: 0.9950372208 RegLoss: -1.5010616637 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5217693668 Acc: 0.8312655087
# Epoch 40 LR: 0.0002922977
# Epoch 41
# train Loss: 0.0236915637 Acc: 0.9937965261 RegLoss: -1.5014109330 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.7252548750 Acc: 0.8014888337
# Epoch 41 LR: 0.0002919209
# Epoch 42
# train Loss: 0.0436028194 Acc: 0.9838709677 RegLoss: -1.5016888279 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.6515159226 Acc: 0.7841191067
# Epoch 42 LR: 0.0002915353
# Epoch 43
# train Loss: 0.0543389638 Acc: 0.9851116625 RegLoss: -1.5019760552 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.6094692047 Acc: 0.8436724566
# Epoch 43 LR: 0.0002911410
# Epoch 44
# train Loss: 0.0273642541 Acc: 0.9950372208 RegLoss: -1.5022208410 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5533937250 Acc: 0.8585607940
# Epoch 44 LR: 0.0002907380
# Epoch 45
# train Loss: 0.0225744684 Acc: 0.9987593052 RegLoss: -1.5024330619 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.4544063968 Acc: 0.8486352357
# Epoch 45 LR: 0.0002903263
# Epoch 46
# train Loss: 0.0461971951 Acc: 0.9863523573 RegLoss: -1.5025503387 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.8820308259 Acc: 0.7084367246
# Epoch 46 LR: 0.0002899060
# Epoch 47
# train Loss: 0.0522984842 Acc: 0.9826302730 RegLoss: -1.5026078618 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.6519469350 Acc: 0.7952853598
# Epoch 47 LR: 0.0002894770
# Epoch 48
# train Loss: 0.0307195712 Acc: 0.9913151365 RegLoss: -1.5026982517 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.8593786010 Acc: 0.7506203474
# Epoch 48 LR: 0.0002890395
# Epoch 49
# train Loss: 0.0098754154 Acc: 0.9975186104 RegLoss: -1.5028295056 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5526696963 Acc: 0.8250620347
# Epoch 49 LR: 0.0002885933
# Epoch 50
# train Loss: 0.0172009017 Acc: 0.9950372208 RegLoss: -1.5029905535 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.7473857445 Acc: 0.7543424318
# Epoch 50 LR: 0.0002881387
# Epoch 51
# train Loss: 0.0235729657 Acc: 0.9925558313 RegLoss: -1.5030809126 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5115237643 Acc: 0.8325062035
# Epoch 51 LR: 0.0002876755
# Epoch 52
# train Loss: 0.0247967573 Acc: 0.9937965261 RegLoss: -1.5032637288 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.7581849218 Acc: 0.8101736973
# Epoch 52 LR: 0.0002872039
# Epoch 53
# train Loss: 0.0399824776 Acc: 0.9888337469 RegLoss: -1.5037049836 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.8721131361 Acc: 0.5397022333
# Epoch 53 LR: 0.0002867238
# Epoch 54
# train Loss: 0.0307456605 Acc: 0.9888337469 RegLoss: -1.5041585705 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.4629375464 Acc: 0.8523573201
# Epoch 54 LR: 0.0002862353
# Epoch 55
# train Loss: 0.0543599895 Acc: 0.9851116625 RegLoss: -1.5046059183 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.8150059963 Acc: 0.7481389578
# Epoch 55 LR: 0.0002857383
# Epoch 56
# train Loss: 0.0497679937 Acc: 0.9875930521 RegLoss: -1.5051320001 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 2.9143536636 Acc: 0.2282878412
# Epoch 56 LR: 0.0002852330
# Epoch 57
# train Loss: 0.0793329219 Acc: 0.9789081886 RegLoss: -1.5057659167 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5893997298 Acc: 0.8337468983
# Epoch 57 LR: 0.0002847194
# Epoch 58
# train Loss: 0.0480191209 Acc: 0.9888337469 RegLoss: -1.5063080897 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.4236972304 Acc: 0.8473945409
# Epoch 58 LR: 0.0002841975
# Epoch 59
# train Loss: 0.0329056688 Acc: 0.9888337469 RegLoss: -1.5074142203 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5620908238 Acc: 0.8312655087
# Epoch 59 LR: 0.0002836673
# Epoch 60
# train Loss: 0.0421052713 Acc: 0.9888337469 RegLoss: -1.5081591804 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 3.2339111759 Acc: 0.3114143921
# Epoch 60 LR: 0.0002831289
# Epoch 61
# train Loss: 0.0445388073 Acc: 0.9863523573 RegLoss: -1.5088631009 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.8270230202 Acc: 0.7580645161
# Epoch 61 LR: 0.0002825823
# Epoch 62
# train Loss: 0.0236471793 Acc: 0.9950372208 RegLoss: -1.5099573298 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.4854629772 Acc: 0.8300248139
# Epoch 62 LR: 0.0002820275
# Epoch 63
# train Loss: 0.0127900504 Acc: 0.9975186104 RegLoss: -1.5112290190 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.5806194944 Acc: 0.8300248139
# Epoch 63 LR: 0.0002814646
# Epoch 64
# train Loss: 0.0203884091 Acc: 0.9937965261 RegLoss: -1.5124619365 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 1.4459623331 Acc: 0.7816377171
# Epoch 64 LR: 0.0002808935
# Epoch 65
# train Loss: 0.0985576252 Acc: 0.9727047146 RegLoss: -1.5124051952 ||tau||: stem = 0.5000 layer4.downsample = 0.5000
# val Loss: 0.7721100234 Acc: 0.7506203474
# Epoch 65 LR: 0.0002803144
# Epoch 66
# train Loss: 0.0397071569 Acc: 0.9875930521 RegLoss: -1.5133797087 ||tau||: stem = 0.5000 layer4.downsample = 0.5001
# val Loss: 0.4649579617 Acc: 0.8746898263
# Epoch 66 LR: 0.0002797273
# Epoch 67
# train Loss: 0.0140010192 Acc: 1.0000000000 RegLoss: -1.5154379367 ||tau||: stem = 0.5000 layer4.downsample = 0.5001
# val Loss: 0.3663765245 Acc: 0.8870967742
# Epoch 67 LR: 0.0002791322
# Epoch 68
# train Loss: 0.0147550311 Acc: 0.9975186104 RegLoss: -1.5175169736 ||tau||: stem = 0.5000 layer4.downsample = 0.5001
# val Loss: 0.5253429779 Acc: 0.8436724566
# Epoch 68 LR: 0.0002785291
# Epoch 69
# train Loss: 0.0298911584 Acc: 0.9900744417 RegLoss: -1.5194900323 ||tau||: stem = 0.5000 layer4.downsample = 0.5001
# val Loss: 0.5008707929 Acc: 0.8424317618
# Epoch 69 LR: 0.0002779181
# Epoch 70
# train Loss: 0.0463468956 Acc: 0.9875930521 RegLoss: -1.5205046832 ||tau||: stem = 0.5000 layer4.downsample = 0.5002
# val Loss: 0.9350512489 Acc: 0.7580645161
# Epoch 70 LR: 0.0002772993
# Epoch 71
# train Loss: 0.0456920041 Acc: 0.9851116625 RegLoss: -1.5210433725 ||tau||: stem = 0.5000 layer4.downsample = 0.5002
# val Loss: 0.5053265849 Acc: 0.8449131514
# Epoch 71 LR: 0.0002766725
# Epoch 72
# train Loss: 0.0232429581 Acc: 0.9937965261 RegLoss: -1.5232503633 ||tau||: stem = 0.5000 layer4.downsample = 0.5003
# val Loss: 0.5433068368 Acc: 0.8411910670
# Epoch 72 LR: 0.0002760380
# Epoch 73
# train Loss: 0.0120490328 Acc: 0.9975186104 RegLoss: -1.5246745703 ||tau||: stem = 0.5000 layer4.downsample = 0.5004
# val Loss: 0.6541593024 Acc: 0.8176178660
# Epoch 73 LR: 0.0002753957
# Epoch 74
# train Loss: 0.0263064379 Acc: 0.9925558313 RegLoss: -1.5261400432 ||tau||: stem = 0.5000 layer4.downsample = 0.5005
# val Loss: 0.6826171152 Acc: 0.7828784119
# Epoch 74 LR: 0.0002747457
# Epoch 75
# train Loss: 0.0404411727 Acc: 0.9826302730 RegLoss: -1.5272845633 ||tau||: stem = 0.5000 layer4.downsample = 0.5006
# val Loss: 0.7108559622 Acc: 0.7878411911
# Epoch 75 LR: 0.0002740880
# Epoch 76
# train Loss: 0.0414440567 Acc: 0.9875930521 RegLoss: -1.5284059423 ||tau||: stem = 0.5000 layer4.downsample = 0.5006
# val Loss: 0.5293030124 Acc: 0.8635235732
# Epoch 76 LR: 0.0002734227
# Epoch 77
# train Loss: 0.0161392656 Acc: 0.9962779156 RegLoss: -1.5295403607 ||tau||: stem = 0.5000 layer4.downsample = 0.5007
# val Loss: 0.5674102126 Acc: 0.7928039702
# Epoch 77 LR: 0.0002727497
# Epoch 78
# train Loss: 0.0221476473 Acc: 0.9913151365 RegLoss: -1.5312324629 ||tau||: stem = 0.5000 layer4.downsample = 0.5008
# val Loss: 0.4889468076 Acc: 0.8511166253
# Epoch 78 LR: 0.0002720692
# Epoch 79
# train Loss: 0.0474518473 Acc: 0.9913151365 RegLoss: -1.5324908726 ||tau||: stem = 0.5000 layer4.downsample = 0.5008
# val Loss: 0.9192115451 Acc: 0.7431761787
# Epoch 79 LR: 0.0002713812
# Epoch 80
# train Loss: 0.0253791216 Acc: 0.9937965261 RegLoss: -1.5346608635 ||tau||: stem = 0.5000 layer4.downsample = 0.5008
# val Loss: 0.6739970947 Acc: 0.8312655087
# Epoch 80 LR: 0.0002706857
# Epoch 81
# train Loss: 0.0127273275 Acc: 0.9962779156 RegLoss: -1.5377450726 ||tau||: stem = 0.5000 layer4.downsample = 0.5009
# val Loss: 0.5252268642 Acc: 0.8635235732
# Epoch 81 LR: 0.0002699827
# Epoch 82
# train Loss: 0.0526671332 Acc: 0.9838709677 RegLoss: -1.5392317813 ||tau||: stem = 0.5000 layer4.downsample = 0.5009
# val Loss: 0.8366918613 Acc: 0.8014888337
# Epoch 82 LR: 0.0002692724
# Epoch 83
# train Loss: 0.0384303907 Acc: 0.9937965261 RegLoss: -1.5414368464 ||tau||: stem = 0.5000 layer4.downsample = 0.5009
# val Loss: 0.7449810239 Acc: 0.8325062035
# Epoch 83 LR: 0.0002685547
# Epoch 84
# train Loss: 0.0197739269 Acc: 0.9962779156 RegLoss: -1.5445599518 ||tau||: stem = 0.5000 layer4.downsample = 0.5010
# val Loss: 0.8977589711 Acc: 0.7096774194
# Epoch 84 LR: 0.0002678297
# Epoch 85
# train Loss: 0.0267437973 Acc: 0.9875930521 RegLoss: -1.5465078842 ||tau||: stem = 0.5000 layer4.downsample = 0.5010
# val Loss: 0.5047200088 Acc: 0.8349875931
# Epoch 85 LR: 0.0002670975
# Epoch 86
# train Loss: 0.0274489041 Acc: 0.9925558313 RegLoss: -1.5481695641 ||tau||: stem = 0.5000 layer4.downsample = 0.5011
# val Loss: 0.6992412075 Acc: 0.8163771712
# Epoch 86 LR: 0.0002663580
# Epoch 87
# train Loss: 0.0190757345 Acc: 0.9975186104 RegLoss: -1.5502470758 ||tau||: stem = 0.5000 layer4.downsample = 0.5011
# val Loss: 0.9522361901 Acc: 0.7841191067
# Epoch 87 LR: 0.0002656114
# Epoch 88
# train Loss: 0.0401052712 Acc: 0.9851116625 RegLoss: -1.5511804932 ||tau||: stem = 0.5000 layer4.downsample = 0.5012
# val Loss: 0.7984744023 Acc: 0.8052109181
# Epoch 88 LR: 0.0002648577
# Epoch 89
# train Loss: 0.0275045776 Acc: 0.9913151365 RegLoss: -1.5535359113 ||tau||: stem = 0.5000 layer4.downsample = 0.5013
# val Loss: 1.1009023353 Acc: 0.7580645161
# Epoch 89 LR: 0.0002640968
# Epoch 90
# train Loss: 0.0502350898 Acc: 0.9826302730 RegLoss: -1.5499876285 ||tau||: stem = 0.5000 layer4.downsample = 0.5014
# val Loss: 0.7052158673 Acc: 0.8238213400
# Epoch 90 LR: 0.0002633290
# Epoch 91
# train Loss: 0.0258725060 Acc: 0.9900744417 RegLoss: -1.5533743913 ||tau||: stem = 0.5000 layer4.downsample = 0.5015
# val Loss: 0.6365359344 Acc: 0.8387096774
# Epoch 91 LR: 0.0002625541
# Epoch 92
# train Loss: 0.0162942528 Acc: 0.9950372208 RegLoss: -1.5561721023 ||tau||: stem = 0.5000 layer4.downsample = 0.5016
# val Loss: 0.3755003509 Acc: 0.8821339950
# Epoch 92 LR: 0.0002617724
# Epoch 93
# train Loss: 0.0127999227 Acc: 0.9950372208 RegLoss: -1.5582155025 ||tau||: stem = 0.5000 layer4.downsample = 0.5017
# val Loss: 0.3778402532 Acc: 0.8697270471
# Epoch 93 LR: 0.0002609837
# Epoch 94
# train Loss: 0.0062303790 Acc: 1.0000000000 RegLoss: -1.5603992034 ||tau||: stem = 0.5000 layer4.downsample = 0.5017
# val Loss: 0.5065724139 Acc: 0.8573200993
# Epoch 94 LR: 0.0002601882
# Epoch 95
# train Loss: 0.0275742426 Acc: 0.9913151365 RegLoss: -1.5616625240 ||tau||: stem = 0.5000 layer4.downsample = 0.5017
# val Loss: 0.5468553935 Acc: 0.8672456576
# Epoch 95 LR: 0.0002593859
# Epoch 96
# train Loss: 0.0065722341 Acc: 0.9975186104 RegLoss: -1.5632810486 ||tau||: stem = 0.5000 layer4.downsample = 0.5017
# val Loss: 0.5379927353 Acc: 0.8585607940
# Epoch 96 LR: 0.0002585769
# Epoch 97
# train Loss: 0.0313842656 Acc: 0.9888337469 RegLoss: -1.5645825032 ||tau||: stem = 0.5000 layer4.downsample = 0.5018
# val Loss: 2.9128121286 Acc: 0.4739454094
# Epoch 97 LR: 0.0002577612
# Epoch 98
# train Loss: 0.0165945978 Acc: 0.9962779156 RegLoss: -1.5663554482 ||tau||: stem = 0.5000 layer4.downsample = 0.5018
# val Loss: 0.4892100392 Acc: 0.8635235732
# Epoch 98 LR: 0.0002569389
# Epoch 99
# train Loss: 0.0036958894 Acc: 1.0000000000 RegLoss: -1.5701558412 ||tau||: stem = 0.5000 layer4.downsample = 0.5018
# val Loss: 0.3831023522 Acc: 0.8908188586
# Epoch 99 LR: 0.0002561100
# Epoch 100
# train Loss: 0.0099843997 Acc: 0.9962779156 RegLoss: -1.5728201890 ||tau||: stem = 0.5000 layer4.downsample = 0.5019
# val Loss: 0.8503857055 Acc: 0.7617866005
# Epoch 100 LR: 0.0002552745
# Epoch 101
# train Loss: 0.0151459329 Acc: 0.9950372208 RegLoss: -1.5744357494 ||tau||: stem = 0.5000 layer4.downsample = 0.5019
# val Loss: 0.6103484844 Acc: 0.8473945409
# Epoch 101 LR: 0.0002544325
# Epoch 102
# train Loss: 0.0307886822 Acc: 0.9875930521 RegLoss: -1.5766087697 ||tau||: stem = 0.5000 layer4.downsample = 0.5019
# val Loss: 0.7957842219 Acc: 0.7803970223
# Epoch 102 LR: 0.0002535841
# Epoch 103
# train Loss: 0.0166077906 Acc: 0.9962779156 RegLoss: -1.5802330033 ||tau||: stem = 0.5000 layer4.downsample = 0.5019
# val Loss: 0.4294046254 Acc: 0.8734491315
# Epoch 103 LR: 0.0002527294
# Epoch 104
# train Loss: 0.0074331754 Acc: 0.9987593052 RegLoss: -1.5833643699 ||tau||: stem = 0.5000 layer4.downsample = 0.5019
# val Loss: 0.3982301929 Acc: 0.8734491315
# Epoch 104 LR: 0.0002518683
# Epoch 105
# train Loss: 0.0111999666 Acc: 0.9962779156 RegLoss: -1.5865616225 ||tau||: stem = 0.5000 layer4.downsample = 0.5020
# val Loss: 0.6034342454 Acc: 0.8411910670
# Epoch 105 LR: 0.0002510009
# Epoch 106
# train Loss: 0.0102544082 Acc: 0.9962779156 RegLoss: -1.5890931568 ||tau||: stem = 0.5000 layer4.downsample = 0.5020
# val Loss: 0.2985881179 Acc: 0.9094292804
# Epoch 106 LR: 0.0002501273
# Epoch 107
# train Loss: 0.0100336663 Acc: 0.9975186104 RegLoss: -1.5925543293 ||tau||: stem = 0.5000 layer4.downsample = 0.5020
# val Loss: 0.4428663238 Acc: 0.8883374690
# Epoch 107 LR: 0.0002492476
# Epoch 108
# train Loss: 0.0254446190 Acc: 0.9888337469 RegLoss: -1.5956566772 ||tau||: stem = 0.5000 layer4.downsample = 0.5020
# val Loss: 0.7905667346 Acc: 0.7853598015
# Epoch 108 LR: 0.0002483617
# Epoch 109
# train Loss: 0.0063673374 Acc: 0.9987593052 RegLoss: -1.5976202074 ||tau||: stem = 0.5000 layer4.downsample = 0.5020
# val Loss: 0.3935252341 Acc: 0.8746898263
# Epoch 109 LR: 0.0002474698
# Epoch 110
# train Loss: 0.0058873956 Acc: 0.9975186104 RegLoss: -1.6019197608 ||tau||: stem = 0.5000 layer4.downsample = 0.5021
# val Loss: 0.3145408380 Acc: 0.8945409429
# Epoch 110 LR: 0.0002465719
# Epoch 111
# train Loss: 0.0087452364 Acc: 0.9987593052 RegLoss: -1.6056917208 ||tau||: stem = 0.5000 layer4.downsample = 0.5022
# val Loss: 0.4566839127 Acc: 0.8684863524
# Epoch 111 LR: 0.0002456680
# Epoch 112
# train Loss: 0.0083359027 Acc: 0.9975186104 RegLoss: -1.6097257093 ||tau||: stem = 0.5000 layer4.downsample = 0.5024
# val Loss: 0.4969625097 Acc: 0.8573200993
# Epoch 112 LR: 0.0002447582
# Epoch 113
# train Loss: 0.0049116990 Acc: 0.9975186104 RegLoss: -1.6130053805 ||tau||: stem = 0.5000 layer4.downsample = 0.5027
# val Loss: 0.6561339248 Acc: 0.8188585608
# Epoch 113 LR: 0.0002438426
# Epoch 114
# train Loss: 0.0199756394 Acc: 0.9925558313 RegLoss: -1.6165643504 ||tau||: stem = 0.5000 layer4.downsample = 0.5030
# val Loss: 0.5072071802 Acc: 0.8560794045
# Epoch 114 LR: 0.0002429212
# Epoch 115
# train Loss: 0.0094702526 Acc: 0.9975186104 RegLoss: -1.6191036964 ||tau||: stem = 0.5000 layer4.downsample = 0.5034
# val Loss: 0.7273170930 Acc: 0.8027295285
# Epoch 115 LR: 0.0002419941
# Epoch 116
# train Loss: 0.0587100004 Acc: 0.9851116625 RegLoss: -1.6201096747 ||tau||: stem = 0.5000 layer4.downsample = 0.5036
# val Loss: 0.7247327611 Acc: 0.8151364764
# Epoch 116 LR: 0.0002410614
# Epoch 117
# train Loss: 0.0103902653 Acc: 0.9962779156 RegLoss: -1.6233541341 ||tau||: stem = 0.5000 layer4.downsample = 0.5038
# val Loss: 0.4754050077 Acc: 0.8833746898
# Epoch 117 LR: 0.0002401230
# Epoch 118
# train Loss: 0.0357717493 Acc: 0.9925558313 RegLoss: -1.6255971850 ||tau||: stem = 0.5000 layer4.downsample = 0.5041
# val Loss: 0.8190194464 Acc: 0.8101736973
# Epoch 118 LR: 0.0002391790
# Epoch 119
# train Loss: 0.0239145878 Acc: 0.9937965261 RegLoss: -1.6288971265 ||tau||: stem = 0.5000 layer4.downsample = 0.5044
# val Loss: 0.7403006188 Acc: 0.8027295285
# Epoch 119 LR: 0.0002382296
# Epoch 120
# train Loss: 0.0151188005 Acc: 0.9950372208 RegLoss: -1.6328343363 ||tau||: stem = 0.5000 layer4.downsample = 0.5047
# val Loss: 0.4112947135 Acc: 0.8808933002
# Epoch 120 LR: 0.0002372748
# Epoch 121
# train Loss: 0.0183693739 Acc: 0.9950372208 RegLoss: -1.6363479996 ||tau||: stem = 0.5000 layer4.downsample = 0.5050
# val Loss: 0.5106365874 Acc: 0.8399503722
# Epoch 121 LR: 0.0002363145
# Epoch 122
# train Loss: 0.0183719149 Acc: 0.9925558313 RegLoss: -1.6386460054 ||tau||: stem = 0.5000 layer4.downsample = 0.5053
# val Loss: 0.8666587298 Acc: 0.7704714640
# Epoch 122 LR: 0.0002353490
# Epoch 123
# train Loss: 0.0177317618 Acc: 0.9950372208 RegLoss: -1.6406413346 ||tau||: stem = 0.5000 layer4.downsample = 0.5055
# val Loss: 0.6961990945 Acc: 0.8076923077
# Epoch 123 LR: 0.0002343782
# Epoch 124
# train Loss: 0.0350886216 Acc: 0.9863523573 RegLoss: -1.6407106077 ||tau||: stem = 0.5000 layer4.downsample = 0.5057
# val Loss: 1.8321989239 Acc: 0.6141439206
# Epoch 124 LR: 0.0002334022
# Epoch 125
# train Loss: 0.0310728293 Acc: 0.9913151365 RegLoss: -1.6442031849 ||tau||: stem = 0.5000 layer4.downsample = 0.5059
# val Loss: 1.0018324660 Acc: 0.7183622829
# Epoch 125 LR: 0.0002324211
# Epoch 126
# train Loss: 0.0130153232 Acc: 0.9962779156 RegLoss: -1.6471216711 ||tau||: stem = 0.5000 layer4.downsample = 0.5062
# val Loss: 0.7882260591 Acc: 0.8473945409
# Epoch 126 LR: 0.0002314349
# Epoch 127
# train Loss: 0.0067320776 Acc: 1.0000000000 RegLoss: -1.6501879769 ||tau||: stem = 0.5000 layer4.downsample = 0.5065
# val Loss: 0.4666504198 Acc: 0.9007444169
# Epoch 127 LR: 0.0002304436
# Epoch 128
# train Loss: 0.0066425226 Acc: 0.9987593052 RegLoss: -1.6526744877 ||tau||: stem = 0.5000 layer4.downsample = 0.5068
# val Loss: 0.8738650324 Acc: 0.8424317618
# Epoch 128 LR: 0.0002294475
# Epoch 129
# train Loss: 0.0110628665 Acc: 0.9987593052 RegLoss: -1.6553954253 ||tau||: stem = 0.5000 layer4.downsample = 0.5072
# val Loss: 0.4850912712 Acc: 0.8808933002
# Epoch 129 LR: 0.0002284464
# Epoch 130
# train Loss: 0.0173401369 Acc: 0.9950372208 RegLoss: -1.6577002106 ||tau||: stem = 0.5000 layer4.downsample = 0.5075
# val Loss: 0.8626341759 Acc: 0.7915632754
# Epoch 130 LR: 0.0002274405
# Epoch 131
# train Loss: 0.0147406415 Acc: 0.9987593052 RegLoss: -1.6592375102 ||tau||: stem = 0.5000 layer4.downsample = 0.5077
# val Loss: 0.5339417167 Acc: 0.8635235732
# Epoch 131 LR: 0.0002264299
# Epoch 132
# train Loss: 0.0046950266 Acc: 1.0000000000 RegLoss: -1.6614981402 ||tau||: stem = 0.5000 layer4.downsample = 0.5079
# val Loss: 0.5741923075 Acc: 0.8399503722
# Epoch 132 LR: 0.0002254145
# Epoch 133
# train Loss: 0.0063276481 Acc: 0.9975186104 RegLoss: -1.6634360147 ||tau||: stem = 0.5000 layer4.downsample = 0.5081
# val Loss: 0.5554534611 Acc: 0.8535980149
# Epoch 133 LR: 0.0002243945
# Epoch 134
# train Loss: 0.0121301550 Acc: 0.9962779156 RegLoss: -1.6659954789 ||tau||: stem = 0.5000 layer4.downsample = 0.5084
# val Loss: 0.6266632044 Acc: 0.8387096774
# Epoch 134 LR: 0.0002233699
# Epoch 135
# train Loss: 0.0225260277 Acc: 0.9937965261 RegLoss: -1.6672442947 ||tau||: stem = 0.5000 layer4.downsample = 0.5087
# val Loss: 1.5980509958 Acc: 0.6588089330
# Epoch 135 LR: 0.0002223408
# Epoch 136
# train Loss: 0.0242194307 Acc: 0.9950372208 RegLoss: -1.6688034671 ||tau||: stem = 0.5000 layer4.downsample = 0.5088
# val Loss: 0.7302467229 Acc: 0.8325062035
# Epoch 136 LR: 0.0002213072
# Epoch 137
# train Loss: 0.0306735690 Acc: 0.9888337469 RegLoss: -1.6709464528 ||tau||: stem = 0.5000 layer4.downsample = 0.5091
# val Loss: 1.0325929328 Acc: 0.6985111663
# Epoch 137 LR: 0.0002202693
# Epoch 138
# train Loss: 0.0421064655 Acc: 0.9900744417 RegLoss: -1.6721276027 ||tau||: stem = 0.5000 layer4.downsample = 0.5091
# val Loss: 0.7723703567 Acc: 0.8387096774
# Epoch 138 LR: 0.0002192270
# Epoch 139
# train Loss: 0.0237252034 Acc: 0.9937965261 RegLoss: -1.6746539377 ||tau||: stem = 0.5000 layer4.downsample = 0.5094
# val Loss: 0.5708577451 Acc: 0.8374689826
# Epoch 139 LR: 0.0002181805
# Epoch 140
# train Loss: 0.0067188392 Acc: 0.9987593052 RegLoss: -1.6777670907 ||tau||: stem = 0.5000 layer4.downsample = 0.5097
# val Loss: 0.5750634797 Acc: 0.8548387097
# Epoch 140 LR: 0.0002171297
# Epoch 141
# train Loss: 0.0029329370 Acc: 1.0000000000 RegLoss: -1.6802093394 ||tau||: stem = 0.5000 layer4.downsample = 0.5100
# val Loss: 0.5393037554 Acc: 0.8622828784
# Epoch 141 LR: 0.0002160749
# Epoch 142
# train Loss: 0.0017377641 Acc: 1.0000000000 RegLoss: -1.6827652552 ||tau||: stem = 0.5000 layer4.downsample = 0.5103
# val Loss: 0.5273778121 Acc: 0.8672456576
# Epoch 142 LR: 0.0002150160
# Epoch 143
# train Loss: 0.0098516997 Acc: 0.9975186104 RegLoss: -1.6844866433 ||tau||: stem = 0.5000 layer4.downsample = 0.5106
# val Loss: 0.5011188783 Acc: 0.8722084367
# Epoch 143 LR: 0.0002139530
# Epoch 144
# train Loss: 0.0015852032 Acc: 1.0000000000 RegLoss: -1.6866271593 ||tau||: stem = 0.5000 layer4.downsample = 0.5109
# val Loss: 0.5783024578 Acc: 0.8598014888
# Epoch 144 LR: 0.0002128862
# Epoch 145
# train Loss: 0.0007901839 Acc: 1.0000000000 RegLoss: -1.6886931616 ||tau||: stem = 0.5000 layer4.downsample = 0.5114
# val Loss: 0.5471369774 Acc: 0.8610421836
# Epoch 145 LR: 0.0002118154
# Epoch 146
# train Loss: 0.0015824354 Acc: 1.0000000000 RegLoss: -1.6906788911 ||tau||: stem = 0.5000 layer4.downsample = 0.5119
# val Loss: 0.5211028762 Acc: 0.8635235732
# Epoch 146 LR: 0.0002107409
# Epoch 147
# train Loss: 0.0122511296 Acc: 0.9962779156 RegLoss: -1.6925266762 ||tau||: stem = 0.5000 layer4.downsample = 0.5126
# val Loss: 0.7943084458 Acc: 0.8089330025
# Epoch 147 LR: 0.0002096626
# Epoch 148
# train Loss: 0.0079063257 Acc: 0.9975186104 RegLoss: -1.6945272794 ||tau||: stem = 0.5000 layer4.downsample = 0.5134
# val Loss: 0.7054612766 Acc: 0.8225806452
# Epoch 148 LR: 0.0002085807
# Epoch 149
# train Loss: 0.0011583956 Acc: 1.0000000000 RegLoss: -1.6970266820 ||tau||: stem = 0.5000 layer4.downsample = 0.5141
# val Loss: 0.5689427762 Acc: 0.8461538462
# Epoch 149 LR: 0.0002074951
# Epoch 150
# train Loss: 0.0043414191 Acc: 0.9975186104 RegLoss: -1.6997026087 ||tau||: stem = 0.5000 layer4.downsample = 0.5146
# val Loss: 0.6919630932 Acc: 0.8238213400
# Epoch 150 LR: 0.0002064060
# Epoch 151
# train Loss: 0.0122931113 Acc: 0.9962779156 RegLoss: -1.7031771001 ||tau||: stem = 0.5000 layer4.downsample = 0.5151
# val Loss: 0.8476909402 Acc: 0.7928039702
# Epoch 151 LR: 0.0002053135
# Epoch 152
# train Loss: 0.0142194985 Acc: 0.9962779156 RegLoss: -1.7047470435 ||tau||: stem = 0.5000 layer4.downsample = 0.5153
# val Loss: 0.5566173950 Acc: 0.8535980149
# Epoch 152 LR: 0.0002042175
# Epoch 153
# train Loss: 0.0313966548 Acc: 0.9900744417 RegLoss: -1.7045356819 ||tau||: stem = 0.5000 layer4.downsample = 0.5154
# val Loss: 1.1870568111 Acc: 0.7022332506
# Epoch 153 LR: 0.0002031182
# Epoch 154
# train Loss: 0.0414729616 Acc: 0.9913151365 RegLoss: -1.7064752132 ||tau||: stem = 0.5000 layer4.downsample = 0.5156
# val Loss: 1.3449770909 Acc: 0.7220843672
# Epoch 154 LR: 0.0002020156
# Epoch 155
# train Loss: 0.0228069918 Acc: 0.9925558313 RegLoss: -1.7081206999 ||tau||: stem = 0.5000 layer4.downsample = 0.5161
# val Loss: 0.7597870135 Acc: 0.7841191067
# Epoch 155 LR: 0.0002009099
# Epoch 156
# train Loss: 0.0115255505 Acc: 0.9975186104 RegLoss: -1.7110612475 ||tau||: stem = 0.5000 layer4.downsample = 0.5166
# val Loss: 0.5755290195 Acc: 0.8573200993
# Epoch 156 LR: 0.0001998010
# Epoch 157
# train Loss: 0.0045196254 Acc: 0.9987593052 RegLoss: -1.7131548280 ||tau||: stem = 0.5000 layer4.downsample = 0.5172
# val Loss: 0.5420835541 Acc: 0.8635235732
# Epoch 157 LR: 0.0001986890
# Epoch 158
# train Loss: 0.0102049988 Acc: 0.9962779156 RegLoss: -1.7148867491 ||tau||: stem = 0.5000 layer4.downsample = 0.5178
# val Loss: 0.4494369374 Acc: 0.8833746898
# Epoch 158 LR: 0.0001975741
# Epoch 159
# train Loss: 0.0214149769 Acc: 0.9925558313 RegLoss: -1.7182722269 ||tau||: stem = 0.5000 layer4.downsample = 0.5185
# val Loss: 0.7044045901 Acc: 0.8424317618
# Epoch 159 LR: 0.0001964562
# Epoch 160
# train Loss: 0.0635523879 Acc: 0.9776674938 RegLoss: 0.8034190907 ||tau||: stem = 0.5000 layer4.downsample = 0.5111
# val Loss: 1.4141644328 Acc: 0.6253101737
# Epoch 160 LR: 0.0001953355
# Epoch 161
# train Loss: 0.0551885521 Acc: 0.9789081886 RegLoss: -0.5402755121 ||tau||: stem = 0.5000 layer4.downsample = 0.5058
# val Loss: 0.8266602850 Acc: 0.8114143921
# Epoch 161 LR: 0.0001942119
# Epoch 162
# train Loss: 0.0296860194 Acc: 0.9875930521 RegLoss: -0.7972041192 ||tau||: stem = 0.5000 layer4.downsample = 0.5060
# val Loss: 0.6954728237 Acc: 0.8039702233
# Epoch 162 LR: 0.0001930857
# Epoch 163
# train Loss: 0.0492781405 Acc: 0.9851116625 RegLoss: -0.9157480271 ||tau||: stem = 0.5000 layer4.downsample = 0.5053
# val Loss: 2.6862025646 Acc: 0.6203473945
# Epoch 163 LR: 0.0001919568
# Epoch 164
# train Loss: 0.0573321240 Acc: 0.9851116625 RegLoss: -0.9961074428 ||tau||: stem = 0.5000 layer4.downsample = 0.5063
# val Loss: 1.1152452140 Acc: 0.7258064516
# Epoch 164 LR: 0.0001908254
# Epoch 165
# train Loss: 0.0220589492 Acc: 0.9925558313 RegLoss: -1.0496803507 ||tau||: stem = 0.5000 layer4.downsample = 0.5059
# val Loss: 0.4354395340 Acc: 0.8734491315
# Epoch 165 LR: 0.0001896914
# Epoch 166
# train Loss: 0.0366780176 Acc: 0.9838709677 RegLoss: -1.1018252450 ||tau||: stem = 0.5000 layer4.downsample = 0.5064
# val Loss: 0.4913933319 Acc: 0.8535980149
# Epoch 166 LR: 0.0001885550
# Epoch 167
# train Loss: 0.0195226591 Acc: 0.9937965261 RegLoss: -1.1319319326 ||tau||: stem = 0.5000 layer4.downsample = 0.5065
# val Loss: 0.4160529757 Acc: 0.8808933002
# Epoch 167 LR: 0.0001874162
# Epoch 168
# train Loss: 0.0187236989 Acc: 0.9975186104 RegLoss: -1.1662856420 ||tau||: stem = 0.5000 layer4.downsample = 0.5063
# val Loss: 0.3792941281 Acc: 0.8846153846
# Epoch 168 LR: 0.0001862751
# Epoch 169
# train Loss: 0.0097972891 Acc: 0.9975186104 RegLoss: -1.1942318397 ||tau||: stem = 0.5000 layer4.downsample = 0.5068
# val Loss: 0.3962784316 Acc: 0.8746898263
# Epoch 169 LR: 0.0001851318
# Epoch 170
# train Loss: 0.0090443491 Acc: 0.9975186104 RegLoss: -1.2201819236 ||tau||: stem = 0.5000 layer4.downsample = 0.5068
# val Loss: 0.5669657690 Acc: 0.8734491315
# Epoch 170 LR: 0.0001839863
# Epoch 171
# train Loss: 0.0208289671 Acc: 0.9975186104 RegLoss: -1.2321750473 ||tau||: stem = 0.5000 layer4.downsample = 0.5072
# val Loss: 0.6225282073 Acc: 0.8610421836
# Epoch 171 LR: 0.0001828388
# Epoch 172
# train Loss: 0.0236984510 Acc: 0.9913151365 RegLoss: -1.2403909968 ||tau||: stem = 0.5000 layer4.downsample = 0.5076
# val Loss: 0.5974828006 Acc: 0.8411910670
# Epoch 172 LR: 0.0001816892
# Epoch 173
# train Loss: 0.0136759150 Acc: 0.9950372208 RegLoss: -1.2546910506 ||tau||: stem = 0.5000 layer4.downsample = 0.5079
# val Loss: 0.5915411487 Acc: 0.8325062035
# Epoch 173 LR: 0.0001805377
# Epoch 174
# train Loss: 0.0155938617 Acc: 0.9962779156 RegLoss: -1.2725737988 ||tau||: stem = 0.5000 layer4.downsample = 0.5078
# val Loss: 0.6225980876 Acc: 0.8498759305
# Epoch 174 LR: 0.0001793843
# Epoch 175
# train Loss: 0.0115351350 Acc: 0.9962779156 RegLoss: -1.2831737658 ||tau||: stem = 0.5000 layer4.downsample = 0.5081
# val Loss: 0.5834139742 Acc: 0.8684863524
# Epoch 175 LR: 0.0001782291
# Epoch 176
# train Loss: 0.0169178328 Acc: 0.9962779156 RegLoss: -1.2888555343 ||tau||: stem = 0.5000 layer4.downsample = 0.5082
# val Loss: 0.5517801554 Acc: 0.8573200993
# Epoch 176 LR: 0.0001770722
# Epoch 177
# train Loss: 0.0252288570 Acc: 0.9913151365 RegLoss: -1.2956463510 ||tau||: stem = 0.5000 layer4.downsample = 0.5084
# val Loss: 0.6097372301 Acc: 0.8374689826
# Epoch 177 LR: 0.0001759136
# Epoch 178
# train Loss: 0.0122249315 Acc: 0.9937965261 RegLoss: -1.3069964056 ||tau||: stem = 0.5000 layer4.downsample = 0.5090
# val Loss: 0.6061498909 Acc: 0.8746898263
# Epoch 178 LR: 0.0001747534
# Epoch 179
# train Loss: 0.0373161684 Acc: 0.9900744417 RegLoss: -1.3048012899 ||tau||: stem = 0.5000 layer4.downsample = 0.5092
# val Loss: 0.6439332839 Acc: 0.8411910670
# Epoch 179 LR: 0.0001735917
# Epoch 180
# train Loss: 0.0069537448 Acc: 0.9975186104 RegLoss: -1.3140102717 ||tau||: stem = 0.5000 layer4.downsample = 0.5091
# val Loss: 0.4988942021 Acc: 0.8771712159
# Epoch 180 LR: 0.0001724286
# Epoch 181
# train Loss: 0.0130345645 Acc: 0.9962779156 RegLoss: -1.3231495563 ||tau||: stem = 0.5000 layer4.downsample = 0.5096
# val Loss: 0.7143573759 Acc: 0.8511166253
# Epoch 181 LR: 0.0001712640
# Epoch 182
# train Loss: 0.0309296531 Acc: 0.9913151365 RegLoss: -1.3288496333 ||tau||: stem = 0.5000 layer4.downsample = 0.5097
# val Loss: 0.7952004818 Acc: 0.8163771712
# Epoch 182 LR: 0.0001700982
# Epoch 183
# train Loss: 0.0039838803 Acc: 1.0000000000 RegLoss: -1.3276447655 ||tau||: stem = 0.5000 layer4.downsample = 0.5098
# val Loss: 0.6242939352 Acc: 0.8585607940
# Epoch 183 LR: 0.0001689312
# Epoch 184
# train Loss: 0.0094344645 Acc: 0.9975186104 RegLoss: -1.3409100662 ||tau||: stem = 0.5000 layer4.downsample = 0.5098
# val Loss: 0.7430449661 Acc: 0.8486352357
# Epoch 184 LR: 0.0001677630
# Epoch 185
# train Loss: 0.0060688747 Acc: 0.9975186104 RegLoss: -1.3483197535 ||tau||: stem = 0.5000 layer4.downsample = 0.5101
# val Loss: 0.6669637865 Acc: 0.8424317618
# Epoch 185 LR: 0.0001665937
# Epoch 186
# train Loss: 0.0119310188 Acc: 0.9937965261 RegLoss: -1.3439186380 ||tau||: stem = 0.5000 layer4.downsample = 0.5105
# val Loss: 0.6028937077 Acc: 0.8424317618
# Epoch 186 LR: 0.0001654234
# Epoch 187
# train Loss: 0.0035272614 Acc: 0.9987593052 RegLoss: -1.3503337096 ||tau||: stem = 0.5000 layer4.downsample = 0.5100
# val Loss: 0.6670137349 Acc: 0.8498759305
# Epoch 187 LR: 0.0001642521
# Epoch 188
# train Loss: 0.0044921733 Acc: 0.9987593052 RegLoss: -1.3548949389 ||tau||: stem = 0.5000 layer4.downsample = 0.5106
# val Loss: 0.5949217256 Acc: 0.8511166253
# Epoch 188 LR: 0.0001630800
# Epoch 189
# train Loss: 0.0062149305 Acc: 0.9987593052 RegLoss: -1.3591133306 ||tau||: stem = 0.5000 layer4.downsample = 0.5112
# val Loss: 0.5899037637 Acc: 0.8585607940
# Epoch 189 LR: 0.0001619071
# Epoch 190
# train Loss: 0.0072694340 Acc: 0.9975186104 RegLoss: -1.3631841048 ||tau||: stem = 0.5000 layer4.downsample = 0.5110
# val Loss: 0.7799609772 Acc: 0.8250620347
# Epoch 190 LR: 0.0001607335
# Epoch 191
# train Loss: 0.0061915684 Acc: 0.9987593052 RegLoss: -1.3611152225 ||tau||: stem = 0.5000 layer4.downsample = 0.5111
# val Loss: 0.7678956276 Acc: 0.8362282878
# Epoch 191 LR: 0.0001595592
# Epoch 192
# train Loss: 0.0039500073 Acc: 0.9975186104 RegLoss: -1.3681180524 ||tau||: stem = 0.5000 layer4.downsample = 0.5113
# val Loss: 0.7745852992 Acc: 0.8200992556
# Epoch 192 LR: 0.0001583843
# Epoch 193
# train Loss: 0.0044756402 Acc: 1.0000000000 RegLoss: -1.3719455498 ||tau||: stem = 0.5000 layer4.downsample = 0.5115
# val Loss: 0.5951735067 Acc: 0.8535980149
# Epoch 193 LR: 0.0001572089
# Epoch 194
# train Loss: 0.0013943915 Acc: 1.0000000000 RegLoss: -1.3756116229 ||tau||: stem = 0.5000 layer4.downsample = 0.5115
# val Loss: 0.5747950461 Acc: 0.8598014888
# Epoch 194 LR: 0.0001560331
# Epoch 195
# train Loss: 0.0062472681 Acc: 0.9950372208 RegLoss: -1.3761079785 ||tau||: stem = 0.5000 layer4.downsample = 0.5114
# val Loss: 0.7350233152 Acc: 0.8064516129
# Epoch 195 LR: 0.0001548569
# Epoch 196
# train Loss: 0.0188994845 Acc: 0.9937965261 RegLoss: -1.3747544670 ||tau||: stem = 0.5000 layer4.downsample = 0.5118
# val Loss: 0.6705668944 Acc: 0.8548387097
# Epoch 196 LR: 0.0001536804
# Epoch 197
# train Loss: 0.0068116929 Acc: 0.9962779156 RegLoss: -1.3763773495 ||tau||: stem = 0.5000 layer4.downsample = 0.5116
# val Loss: 0.5399756915 Acc: 0.8722084367
# Epoch 197 LR: 0.0001525037
# Epoch 198
# train Loss: 0.0234804948 Acc: 0.9888337469 RegLoss: -1.3745381033 ||tau||: stem = 0.5000 layer4.downsample = 0.5121
# val Loss: 0.8598585111 Acc: 0.7915632754
# Epoch 198 LR: 0.0001513269
# Epoch 199
# train Loss: 0.0032693243 Acc: 0.9987593052 RegLoss: -1.3747273400 ||tau||: stem = 0.5000 layer4.downsample = 0.5118
# val Loss: 0.5655421693 Acc: 0.8548387097
# Epoch 199 LR: 0.0001501500
# Epoch 200
# train Loss: 0.0198502940 Acc: 0.9950372208 RegLoss: -1.3791306149 ||tau||: stem = 0.5000 layer4.downsample = 0.5122
# val Loss: 0.7328469698 Acc: 0.8076923077
# Epoch 200 LR: 0.0001489731
# Epoch 201
# train Loss: 0.0156364802 Acc: 0.9950372208 RegLoss: -1.3758568249 ||tau||: stem = 0.5000 layer4.downsample = 0.5120
# val Loss: 0.5229693478 Acc: 0.8387096774
# Epoch 201 LR: 0.0001477963
# Epoch 202
# train Loss: 0.0159891274 Acc: 0.9937965261 RegLoss: -1.3821969346 ||tau||: stem = 0.5000 layer4.downsample = 0.5123
# val Loss: 0.7219702036 Acc: 0.8176178660
# Epoch 202 LR: 0.0001466196
# Epoch 203
# train Loss: 0.0119001550 Acc: 0.9975186104 RegLoss: -1.3797696938 ||tau||: stem = 0.5000 layer4.downsample = 0.5128
# val Loss: 0.5090293920 Acc: 0.8486352357
# Epoch 203 LR: 0.0001454431
# Epoch 204
# train Loss: 0.0012644354 Acc: 1.0000000000 RegLoss: -1.3818425082 ||tau||: stem = 0.5000 layer4.downsample = 0.5126
# val Loss: 0.4713476514 Acc: 0.8734491315
# Epoch 204 LR: 0.0001442669
# Epoch 205
# train Loss: 0.0017334044 Acc: 1.0000000000 RegLoss: -1.3830757552 ||tau||: stem = 0.5000 layer4.downsample = 0.5127
# val Loss: 0.4540703884 Acc: 0.8734491315
# Epoch 205 LR: 0.0001430911
# Epoch 206
# train Loss: 0.0031166258 Acc: 0.9987593052 RegLoss: -1.3870627898 ||tau||: stem = 0.5000 layer4.downsample = 0.5128
# val Loss: 0.4524154294 Acc: 0.8734491315
# Epoch 206 LR: 0.0001419157
# Epoch 207
# train Loss: 0.0110503860 Acc: 0.9937965261 RegLoss: -1.3793543852 ||tau||: stem = 0.5000 layer4.downsample = 0.5130
# val Loss: 0.5184433209 Acc: 0.8411910670
# Epoch 207 LR: 0.0001407408
# Epoch 208
# train Loss: 0.0131376029 Acc: 0.9962779156 RegLoss: -1.3798924232 ||tau||: stem = 0.5000 layer4.downsample = 0.5125
# val Loss: 0.4072685517 Acc: 0.8759305211
# Epoch 208 LR: 0.0001395665
# Epoch 209
# train Loss: 0.0016618164 Acc: 1.0000000000 RegLoss: -1.3817066803 ||tau||: stem = 0.5000 layer4.downsample = 0.5130
# val Loss: 0.4942104589 Acc: 0.8449131514
# Epoch 209 LR: 0.0001383929
# Epoch 210
# train Loss: 0.0039367077 Acc: 0.9975186104 RegLoss: -1.3892994347 ||tau||: stem = 0.5000 layer4.downsample = 0.5130
# val Loss: 0.5571283193 Acc: 0.8349875931
# Epoch 210 LR: 0.0001372200
# Epoch 211
# train Loss: 0.0087853231 Acc: 0.9950372208 RegLoss: -1.3869003809 ||tau||: stem = 0.5000 layer4.downsample = 0.5133
# val Loss: 0.5044890533 Acc: 0.8486352357
# Epoch 211 LR: 0.0001360479
# Epoch 212
# train Loss: 0.0040831055 Acc: 0.9987593052 RegLoss: -1.3915856263 ||tau||: stem = 0.5000 layer4.downsample = 0.5132
# val Loss: 0.7366108768 Acc: 0.7853598015
# Epoch 212 LR: 0.0001348766
# Epoch 213
# train Loss: 0.0037138924 Acc: 0.9987593052 RegLoss: -1.3921496342 ||tau||: stem = 0.5000 layer4.downsample = 0.5131
# val Loss: 0.6432433929 Acc: 0.8114143921
# Epoch 213 LR: 0.0001337063
# Epoch 214
# train Loss: 0.0010798895 Acc: 1.0000000000 RegLoss: -1.3955712100 ||tau||: stem = 0.5000 layer4.downsample = 0.5135
# val Loss: 0.6294880827 Acc: 0.8275434243
# Epoch 214 LR: 0.0001325370
# Epoch 215
# train Loss: 0.0124487429 Acc: 0.9975186104 RegLoss: -1.3968551180 ||tau||: stem = 0.5000 layer4.downsample = 0.5132
# val Loss: 0.6267920941 Acc: 0.8325062035
# Epoch 215 LR: 0.0001313688
# Epoch 216
# train Loss: 0.0042792985 Acc: 0.9987593052 RegLoss: -1.3928125274 ||tau||: stem = 0.5000 layer4.downsample = 0.5131
# val Loss: 0.5602470907 Acc: 0.8349875931
# Epoch 216 LR: 0.0001302018
# Epoch 217
# train Loss: 0.0211810806 Acc: 0.9950372208 RegLoss: -1.3921434119 ||tau||: stem = 0.5000 layer4.downsample = 0.5135
# val Loss: 0.5966966785 Acc: 0.8337468983
# Epoch 217 LR: 0.0001290360
# Epoch 218
# train Loss: 0.0089504596 Acc: 0.9975186104 RegLoss: -1.3942930435 ||tau||: stem = 0.5000 layer4.downsample = 0.5130
# val Loss: 0.5204453611 Acc: 0.8486352357
# Epoch 218 LR: 0.0001278714
# Epoch 219
# train Loss: 0.0037762686 Acc: 0.9987593052 RegLoss: -1.3969079673 ||tau||: stem = 0.5000 layer4.downsample = 0.5136
# val Loss: 0.6447197522 Acc: 0.8312655087
# Epoch 219 LR: 0.0001267083
# Epoch 220
# train Loss: 0.0176453383 Acc: 0.9925558313 RegLoss: -1.3988015891 ||tau||: stem = 0.5000 layer4.downsample = 0.5136
# val Loss: 0.4161284194 Acc: 0.8722084367
# Epoch 220 LR: 0.0001255466
# Epoch 221
# train Loss: 0.0129570706 Acc: 0.9987593052 RegLoss: -1.3982003075 ||tau||: stem = 0.5000 layer4.downsample = 0.5134
# val Loss: 0.3549498294 Acc: 0.8945409429
# Epoch 221 LR: 0.0001243864
# Epoch 222
# train Loss: 0.0070901101 Acc: 0.9987593052 RegLoss: -1.3935603814 ||tau||: stem = 0.5000 layer4.downsample = 0.5137
# val Loss: 0.4255744737 Acc: 0.8610421836
# Epoch 222 LR: 0.0001232278
# Epoch 223
# train Loss: 0.0140769699 Acc: 0.9975186104 RegLoss: -1.3989162120 ||tau||: stem = 0.5000 layer4.downsample = 0.5135
# val Loss: 0.5273567430 Acc: 0.8486352357
# Epoch 223 LR: 0.0001220709
# Epoch 224
# train Loss: 0.0030760109 Acc: 0.9987593052 RegLoss: -1.3974471956 ||tau||: stem = 0.5000 layer4.downsample = 0.5137
# val Loss: 0.4778764978 Acc: 0.8560794045
# Epoch 224 LR: 0.0001209157
# Epoch 225
# train Loss: 0.0192048056 Acc: 0.9962779156 RegLoss: -1.3973956854 ||tau||: stem = 0.5000 layer4.downsample = 0.5139
# val Loss: 0.4835687884 Acc: 0.8722084367
# Epoch 225 LR: 0.0001197623
# Epoch 226
# train Loss: 0.0013330839 Acc: 1.0000000000 RegLoss: -1.4021213072 ||tau||: stem = 0.5000 layer4.downsample = 0.5139
# val Loss: 0.4320417704 Acc: 0.8796526055
# Epoch 226 LR: 0.0001186108
# Epoch 227
# train Loss: 0.0073286907 Acc: 0.9962779156 RegLoss: -1.3979128002 ||tau||: stem = 0.5000 layer4.downsample = 0.5141
# val Loss: 0.5321099061 Acc: 0.8362282878
# Epoch 227 LR: 0.0001174612
# Epoch 228
# train Loss: 0.0036027142 Acc: 0.9987593052 RegLoss: -1.4018886418 ||tau||: stem = 0.5000 layer4.downsample = 0.5140
# val Loss: 0.5604377345 Acc: 0.8325062035
# Epoch 228 LR: 0.0001163137
# Epoch 229
# train Loss: 0.0034197360 Acc: 0.9975186104 RegLoss: -1.4023981411 ||tau||: stem = 0.5000 layer4.downsample = 0.5141
# val Loss: 0.7786415261 Acc: 0.7903225806
# Epoch 229 LR: 0.0001151682
# Epoch 230
# train Loss: 0.0108509992 Acc: 0.9962779156 RegLoss: -1.4025752334 ||tau||: stem = 0.5000 layer4.downsample = 0.5139
# val Loss: 0.5723915255 Acc: 0.8287841191
# Epoch 230 LR: 0.0001140249
# Epoch 231
# train Loss: 0.0043888041 Acc: 0.9987593052 RegLoss: -1.4032680805 ||tau||: stem = 0.5000 layer4.downsample = 0.5140
# val Loss: 0.4328953004 Acc: 0.8622828784
# Epoch 231 LR: 0.0001128838
# Epoch 232
# train Loss: 0.0078920697 Acc: 0.9962779156 RegLoss: -1.4028896167 ||tau||: stem = 0.5000 layer4.downsample = 0.5143
# val Loss: 0.6062839158 Acc: 0.8114143921
# Epoch 232 LR: 0.0001117450
# Epoch 233
# train Loss: 0.0127426187 Acc: 0.9937965261 RegLoss: -1.4045323376 ||tau||: stem = 0.5000 layer4.downsample = 0.5141
# val Loss: 0.5053659358 Acc: 0.8573200993
# Epoch 233 LR: 0.0001106086
# Epoch 234
# train Loss: 0.0027846781 Acc: 1.0000000000 RegLoss: -1.3981538295 ||tau||: stem = 0.5000 layer4.downsample = 0.5140
# val Loss: 0.7320052899 Acc: 0.8027295285
# Epoch 234 LR: 0.0001094746
# Epoch 235
# train Loss: 0.0059544237 Acc: 0.9975186104 RegLoss: -1.4048757243 ||tau||: stem = 0.5000 layer4.downsample = 0.5141
# val Loss: 0.7030787788 Acc: 0.8213399504
# Epoch 235 LR: 0.0001083432
# Epoch 236
# train Loss: 0.0079936860 Acc: 0.9975186104 RegLoss: -1.4000535325 ||tau||: stem = 0.5000 layer4.downsample = 0.5141
# val Loss: 0.6814682556 Acc: 0.8263027295
# Epoch 236 LR: 0.0001072143
# Epoch 237
# train Loss: 0.0159277284 Acc: 0.9950372208 RegLoss: -1.4023859391 ||tau||: stem = 0.5000 layer4.downsample = 0.5143
# val Loss: 0.7935040302 Acc: 0.8027295285
# Epoch 237 LR: 0.0001060881
# Epoch 238
# train Loss: 0.0128225523 Acc: 0.9975186104 RegLoss: -1.4010211244 ||tau||: stem = 0.5000 layer4.downsample = 0.5144
# val Loss: 0.9288218283 Acc: 0.8064516129
# Epoch 238 LR: 0.0001049645
# Epoch 239
# train Loss: 0.0023034434 Acc: 0.9987593052 RegLoss: -1.4029872722 ||tau||: stem = 0.5000 layer4.downsample = 0.5143
# val Loss: 0.8209345567 Acc: 0.8238213400
# Epoch 239 LR: 0.0001038438
# Epoch 240
# train Loss: 0.0054580001 Acc: 0.9975186104 RegLoss: -1.4039026253 ||tau||: stem = 0.5000 layer4.downsample = 0.5142
# val Loss: 0.7420932889 Acc: 0.8138957816
# Epoch 240 LR: 0.0001027259
# Epoch 241
# train Loss: 0.0015959295 Acc: 1.0000000000 RegLoss: -1.4028587253 ||tau||: stem = 0.5000 layer4.downsample = 0.5144
# val Loss: 0.8235332717 Acc: 0.7903225806
# Epoch 241 LR: 0.0001016110
# Epoch 242
# train Loss: 0.0024744497 Acc: 0.9987593052 RegLoss: -1.4077739807 ||tau||: stem = 0.5000 layer4.downsample = 0.5143
# val Loss: 0.9328540473 Acc: 0.7928039702
# Epoch 242 LR: 0.0001004990
# Epoch 243
# train Loss: 0.0041677905 Acc: 0.9975186104 RegLoss: -1.4065480632 ||tau||: stem = 0.5000 layer4.downsample = 0.5145
# val Loss: 0.8192707613 Acc: 0.7977667494
# Epoch 243 LR: 0.0000993901
# Epoch 244
# train Loss: 0.0127911976 Acc: 0.9962779156 RegLoss: -1.4058805639 ||tau||: stem = 0.5000 layer4.downsample = 0.5142
# val Loss: 0.8698165676 Acc: 0.8014888337
# Epoch 244 LR: 0.0000982844
# Epoch 245
# train Loss: 0.0030406339 Acc: 1.0000000000 RegLoss: -1.4084973832 ||tau||: stem = 0.5000 layer4.downsample = 0.5146
# val Loss: 0.8028368404 Acc: 0.8200992556
# Epoch 245 LR: 0.0000971818
# Epoch 246
# train Loss: 0.0022623401 Acc: 0.9987593052 RegLoss: -1.4088386235 ||tau||: stem = 0.5000 layer4.downsample = 0.5146
# val Loss: 0.7443315834 Acc: 0.8188585608
# Epoch 246 LR: 0.0000960825
# Epoch 247
# train Loss: 0.0032058914 Acc: 0.9987593052 RegLoss: -1.4092066205 ||tau||: stem = 0.5000 layer4.downsample = 0.5146
# val Loss: 0.6954852250 Acc: 0.8325062035
# Epoch 247 LR: 0.0000949865
# Epoch 248
# ...
# Epoch 317 LR: 0.0000303173
# Epoch 318
# train Loss: 0.0009891050 Acc: 1.0000000000 RegLoss: -1.4336436656 ||tau||: stem = 0.5000 layer4.downsample = 0.5154
# val Loss: 0.3924220131 Acc: 0.8945409429
# Epoch 318 LR: 0.0000296143
# Epoch 319
# train Loss: 0.0065896046 Acc: 0.9987593052 RegLoss: -1.4357253919 ||tau||: stem = 0.5000 layer4.downsample = 0.5155
# val Loss: 0.4757788834 Acc: 0.8610421836
# Epoch 319 LR: 0.0000289188
# Epoch 320
# train Loss: 0.0016406033 Acc: 1.0000000000 RegLoss: -1.4358138754 ||tau||: stem = 0.5000 layer4.downsample = 0.5156
# val Loss: 0.3995275317 Acc: 0.8870967742
# Epoch 320 LR: 0.0000282308
# Epoch 321
# train Loss: 0.0109055629 Acc: 0.9962779156 RegLoss: -1.4338615633 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.4160204094 Acc: 0.8833746898
# Epoch 321 LR: 0.0000275503
# Epoch 322
# train Loss: 0.0006547501 Acc: 1.0000000000 RegLoss: -1.4323476621 ||tau||: stem = 0.5000 layer4.downsample = 0.5156
# val Loss: 0.3632925733 Acc: 0.8945409429
# Epoch 322 LR: 0.0000268773
# Epoch 323
# train Loss: 0.0008224135 Acc: 1.0000000000 RegLoss: -1.4329944246 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3840703551 Acc: 0.8920595533
# Epoch 323 LR: 0.0000262120
# Epoch 324
# train Loss: 0.0004401959 Acc: 1.0000000000 RegLoss: -1.4344499871 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3467741257 Acc: 0.9007444169
# Epoch 324 LR: 0.0000255543
# Epoch 325
# train Loss: 0.0004587806 Acc: 1.0000000000 RegLoss: -1.4357377663 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3450815974 Acc: 0.8982630273
# Epoch 325 LR: 0.0000249043
# Epoch 326
# train Loss: 0.0003335606 Acc: 1.0000000000 RegLoss: -1.4348009209 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.3843311047 Acc: 0.8933002481
# Epoch 326 LR: 0.0000242620
# Epoch 327
# train Loss: 0.0005957420 Acc: 1.0000000000 RegLoss: -1.4367259791 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3928599689 Acc: 0.8908188586
# Epoch 327 LR: 0.0000236275
# Epoch 328
# train Loss: 0.0008631168 Acc: 1.0000000000 RegLoss: -1.4359618973 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.3970571341 Acc: 0.8908188586
# Epoch 328 LR: 0.0000230007
# Epoch 329
# train Loss: 0.0004994053 Acc: 1.0000000000 RegLoss: -1.4334680342 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3738514755 Acc: 0.8970223325
# Epoch 329 LR: 0.0000223819
# Epoch 330
# train Loss: 0.0013372651 Acc: 0.9987593052 RegLoss: -1.4372971670 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3538054634 Acc: 0.8982630273
# Epoch 330 LR: 0.0000217709
# Epoch 331
# train Loss: 0.0003323190 Acc: 1.0000000000 RegLoss: -1.4372310828 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.3790176998 Acc: 0.8883374690
# Epoch 331 LR: 0.0000211678
# Epoch 332
# train Loss: 0.0013519201 Acc: 0.9987593052 RegLoss: -1.4376600880 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.3987349140 Acc: 0.8870967742
# Epoch 332 LR: 0.0000205727
# Epoch 333
# train Loss: 0.0003824737 Acc: 1.0000000000 RegLoss: -1.4355521708 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.4153736078 Acc: 0.8846153846
# Epoch 333 LR: 0.0000199856
# Epoch 334
# train Loss: 0.0012192751 Acc: 1.0000000000 RegLoss: -1.4382645232 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.4547154785 Acc: 0.8784119107
# Epoch 334 LR: 0.0000194065
# Epoch 335
# train Loss: 0.0047855738 Acc: 0.9975186104 RegLoss: -1.4350566051 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.3598445701 Acc: 0.8933002481
# Epoch 335 LR: 0.0000188354
# Epoch 336
# train Loss: 0.0042165818 Acc: 0.9987593052 RegLoss: -1.4382510537 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.3870675672 Acc: 0.8895781638
# Epoch 336 LR: 0.0000182725
# Epoch 337
# train Loss: 0.0007306485 Acc: 1.0000000000 RegLoss: -1.4380373839 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.4117646663 Acc: 0.8858560794
# Epoch 337 LR: 0.0000177177
# Epoch 338
# train Loss: 0.0022098593 Acc: 0.9987593052 RegLoss: -1.4364464425 ||tau||: stem = 0.5000 layer4.downsample = 0.5157
# val Loss: 0.4105216303 Acc: 0.8870967742
# Epoch 338 LR: 0.0000171711
# Epoch 339
# train Loss: 0.0061097082 Acc: 0.9987593052 RegLoss: -1.4379730722 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4345602258 Acc: 0.8796526055
# Epoch 339 LR: 0.0000166327
# Epoch 340
# train Loss: 0.0013124502 Acc: 1.0000000000 RegLoss: -1.4381725534 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4301386719 Acc: 0.8870967742
# Epoch 340 LR: 0.0000161025
# Epoch 341
# train Loss: 0.0004599627 Acc: 1.0000000000 RegLoss: -1.4389770203 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4307299802 Acc: 0.8808933002
# Epoch 341 LR: 0.0000155806
# Epoch 342
# train Loss: 0.0059890757 Acc: 0.9975186104 RegLoss: -1.4411865195 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.3861046359 Acc: 0.8957816377
# Epoch 342 LR: 0.0000150670
# Epoch 343
# train Loss: 0.0013233439 Acc: 1.0000000000 RegLoss: -1.4380770292 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4643734146 Acc: 0.8746898263
# Epoch 343 LR: 0.0000145617
# Epoch 344
# train Loss: 0.0006245411 Acc: 1.0000000000 RegLoss: -1.4377512683 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.4351462488 Acc: 0.8746898263
# Epoch 344 LR: 0.0000140647
# Epoch 345
# train Loss: 0.0006894263 Acc: 1.0000000000 RegLoss: -1.4349661524 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4943454848 Acc: 0.8697270471
# Epoch 345 LR: 0.0000135762
# Epoch 346
# train Loss: 0.0003240943 Acc: 1.0000000000 RegLoss: -1.4387631875 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.4807400932 Acc: 0.8709677419
# Epoch 346 LR: 0.0000130961
# Epoch 347
# train Loss: 0.0016039303 Acc: 0.9987593052 RegLoss: -1.4369709666 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4455235641 Acc: 0.8808933002
# Epoch 347 LR: 0.0000126245
# Epoch 348
# train Loss: 0.0002096250 Acc: 1.0000000000 RegLoss: -1.4377838545 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.5050490428 Acc: 0.8697270471
# Epoch 348 LR: 0.0000121613
# Epoch 349
# train Loss: 0.0012036945 Acc: 1.0000000000 RegLoss: -1.4381137291 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4711195315 Acc: 0.8746898263
# Epoch 349 LR: 0.0000117067
# Epoch 350
# train Loss: 0.0037035740 Acc: 0.9987593052 RegLoss: -1.4380972666 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4559216554 Acc: 0.8771712159
# Epoch 350 LR: 0.0000112605
# Epoch 351
# train Loss: 0.0035474445 Acc: 0.9987593052 RegLoss: -1.4385737015 ||tau||: stem = 0.5000 layer4.downsample = 0.5158
# val Loss: 0.4841262867 Acc: 0.8697270471
# Epoch 351 LR: 0.0000108230
# Epoch 352
# train Loss: 0.0004067512 Acc: 1.0000000000 RegLoss: -1.4377137133 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4518620269 Acc: 0.8771712159
# Epoch 352 LR: 0.0000103940
# Epoch 353
# train Loss: 0.0006232134 Acc: 1.0000000000 RegLoss: -1.4375661197 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4200639839 Acc: 0.8858560794
# Epoch 353 LR: 0.0000099737
# Epoch 354
# train Loss: 0.0034408726 Acc: 0.9987593052 RegLoss: -1.4387722607 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4858745685 Acc: 0.8635235732
# Epoch 354 LR: 0.0000095620
# Epoch 355
# train Loss: 0.0002108330 Acc: 1.0000000000 RegLoss: -1.4420942293 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4767651049 Acc: 0.8697270471
# Epoch 355 LR: 0.0000091590
# Epoch 356
# train Loss: 0.0012412859 Acc: 1.0000000000 RegLoss: -1.4396444707 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4775779849 Acc: 0.8672456576
# Epoch 356 LR: 0.0000087647
# Epoch 357
# train Loss: 0.0024636496 Acc: 0.9987593052 RegLoss: -1.4386191759 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4504553454 Acc: 0.8697270471
# Epoch 357 LR: 0.0000083791
# Epoch 358
# train Loss: 0.0017914874 Acc: 0.9987593052 RegLoss: -1.4400936759 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4553919742 Acc: 0.8734491315
# Epoch 358 LR: 0.0000080023
# Epoch 359
# train Loss: 0.0011751069 Acc: 1.0000000000 RegLoss: -1.4406143374 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4829304879 Acc: 0.8622828784
# Epoch 359 LR: 0.0000076342
# Epoch 360
# train Loss: 0.0007692448 Acc: 1.0000000000 RegLoss: -1.4417571598 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4614231297 Acc: 0.8709677419
# Epoch 360 LR: 0.0000072749
# Epoch 361
# train Loss: 0.0072312995 Acc: 0.9975186104 RegLoss: -1.4409698526 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.5099843656 Acc: 0.8635235732
# Epoch 361 LR: 0.0000069244
# Epoch 362
# train Loss: 0.0003125882 Acc: 1.0000000000 RegLoss: -1.4403060755 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4437410418 Acc: 0.8771712159
# Epoch 362 LR: 0.0000065828
# Epoch 363
# train Loss: 0.0007208864 Acc: 1.0000000000 RegLoss: -1.4405611407 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4060071497 Acc: 0.8846153846
# Epoch 363 LR: 0.0000062500
# Epoch 364
# train Loss: 0.0007220159 Acc: 1.0000000000 RegLoss: -1.4411393354 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4449825818 Acc: 0.8709677419
# Epoch 364 LR: 0.0000059261
# Epoch 365
# train Loss: 0.0007014054 Acc: 1.0000000000 RegLoss: -1.4407605726 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4164537255 Acc: 0.8808933002
# Epoch 365 LR: 0.0000056111
# Epoch 366
# train Loss: 0.0004434296 Acc: 1.0000000000 RegLoss: -1.4422391357 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4103787409 Acc: 0.8833746898
# Epoch 366 LR: 0.0000053050
# Epoch 367
# train Loss: 0.0020655274 Acc: 0.9987593052 RegLoss: -1.4411554967 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4494743389 Acc: 0.8771712159
# Epoch 367 LR: 0.0000050078
# Epoch 368
# train Loss: 0.0003033368 Acc: 1.0000000000 RegLoss: -1.4385400301 ||tau||: stem = 0.5000 layer4.downsample = 0.5161
# val Loss: 0.4139617732 Acc: 0.8846153846
# Epoch 368 LR: 0.0000047196
# Epoch 369
# train Loss: 0.0029806158 Acc: 0.9987593052 RegLoss: -1.4422316513 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4182330102 Acc: 0.8833746898
# Epoch 369 LR: 0.0000044404
# Epoch 370
# train Loss: 0.0007198905 Acc: 1.0000000000 RegLoss: -1.4382566776 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4566435251 Acc: 0.8759305211
# Epoch 370 LR: 0.0000041701
# Epoch 371
# train Loss: 0.0004707231 Acc: 1.0000000000 RegLoss: -1.4436667853 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3972563949 Acc: 0.8870967742
# Epoch 371 LR: 0.0000039089
# Epoch 372
# train Loss: 0.0001674062 Acc: 1.0000000000 RegLoss: -1.4406530067 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.4092462445 Acc: 0.8821339950
# Epoch 372 LR: 0.0000036566
# Epoch 373
# train Loss: 0.0003500615 Acc: 1.0000000000 RegLoss: -1.4423937360 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4371935219 Acc: 0.8746898263
# Epoch 373 LR: 0.0000034135
# Epoch 374
# train Loss: 0.0030249061 Acc: 0.9987593052 RegLoss: -1.4402167818 ||tau||: stem = 0.5000 layer4.downsample = 0.5161
# val Loss: 0.4602804798 Acc: 0.8746898263
# Epoch 374 LR: 0.0000031793
# Epoch 375
# train Loss: 0.0008792232 Acc: 1.0000000000 RegLoss: -1.4424760587 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4377577769 Acc: 0.8759305211
# Epoch 375 LR: 0.0000029543
# Epoch 376
# train Loss: 0.0001839270 Acc: 1.0000000000 RegLoss: -1.4418332127 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3836876978 Acc: 0.8883374690
# Epoch 376 LR: 0.0000027383
# Epoch 377
# train Loss: 0.0001291127 Acc: 1.0000000000 RegLoss: -1.4419061011 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3984626320 Acc: 0.8870967742
# Epoch 377 LR: 0.0000025314
# Epoch 378
# train Loss: 0.0009530120 Acc: 1.0000000000 RegLoss: -1.4414499401 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3889380395 Acc: 0.8883374690
# Epoch 378 LR: 0.0000023336
# Epoch 379
# train Loss: 0.0017811856 Acc: 1.0000000000 RegLoss: -1.4441801688 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3557823782 Acc: 0.9019851117
# Epoch 379 LR: 0.0000021449
# Epoch 380
# train Loss: 0.0003887753 Acc: 1.0000000000 RegLoss: -1.4405212882 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4852723028 Acc: 0.8672456576
# Epoch 380 LR: 0.0000019654
# Epoch 381
# train Loss: 0.0005606800 Acc: 1.0000000000 RegLoss: -1.4415241586 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4182757774 Acc: 0.8784119107
# Epoch 381 LR: 0.0000017950
# Epoch 382
# train Loss: 0.0023013464 Acc: 0.9987593052 RegLoss: -1.4423325065 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4258066485 Acc: 0.8821339950
# Epoch 382 LR: 0.0000016337
# Epoch 383
# train Loss: 0.0008128941 Acc: 1.0000000000 RegLoss: -1.4424470710 ||tau||: stem = 0.5000 layer4.downsample = 0.5159
# val Loss: 0.3629189738 Acc: 0.8970223325
# Epoch 383 LR: 0.0000014816
# Epoch 384
# train Loss: 0.0017686112 Acc: 0.9987593052 RegLoss: -1.4423340686 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3982179440 Acc: 0.8883374690
# Epoch 384 LR: 0.0000013387
# Epoch 385
# train Loss: 0.0002431413 Acc: 1.0000000000 RegLoss: -1.4428264935 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3481780361 Acc: 0.8995037221
# Epoch 385 LR: 0.0000012050
# Epoch 386
# train Loss: 0.0014964881 Acc: 0.9987593052 RegLoss: -1.4434121652 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3617187932 Acc: 0.9044665012
# Epoch 386 LR: 0.0000010804
# Epoch 387
# train Loss: 0.0020170403 Acc: 0.9987593052 RegLoss: -1.4433939933 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4365761476 Acc: 0.8821339950
# Epoch 387 LR: 0.0000009650
# Epoch 388
# train Loss: 0.0002593599 Acc: 1.0000000000 RegLoss: -1.4421313770 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4158668891 Acc: 0.8833746898
# Epoch 388 LR: 0.0000008589
# Epoch 389
# train Loss: 0.0002837978 Acc: 1.0000000000 RegLoss: -1.4399427454 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4237572146 Acc: 0.8808933002
# Epoch 389 LR: 0.0000007619
# Epoch 390
# train Loss: 0.0006854596 Acc: 1.0000000000 RegLoss: -1.4414145417 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3863938974 Acc: 0.8895781638
# Epoch 390 LR: 0.0000006742
# Epoch 391
# train Loss: 0.0007491197 Acc: 1.0000000000 RegLoss: -1.4417467665 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4116967603 Acc: 0.8784119107
# Epoch 391 LR: 0.0000005957
# Epoch 392
# train Loss: 0.0008953401 Acc: 1.0000000000 RegLoss: -1.4418794854 ||tau||: stem = 0.5000 layer4.downsample = 0.5161
# val Loss: 0.4264806797 Acc: 0.8821339950
# Epoch 392 LR: 0.0000005264
# Epoch 393
# train Loss: 0.0023708628 Acc: 0.9987593052 RegLoss: -1.4418715147 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4460044605 Acc: 0.8771712159
# Epoch 393 LR: 0.0000004664
# Epoch 394
# train Loss: 0.0027279677 Acc: 0.9987593052 RegLoss: -1.4430037959 ||tau||: stem = 0.5000 layer4.downsample = 0.5161
# val Loss: 0.4287940994 Acc: 0.8759305211
# Epoch 394 LR: 0.0000004155
# Epoch 395
# train Loss: 0.0010669723 Acc: 1.0000000000 RegLoss: -1.4416433537 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3877782840 Acc: 0.8933002481
# Epoch 395 LR: 0.0000003739
# Epoch 396
# train Loss: 0.0012035878 Acc: 1.0000000000 RegLoss: -1.4419988911 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4264025290 Acc: 0.8784119107
# Epoch 396 LR: 0.0000003416
# Epoch 397
# train Loss: 0.0008865571 Acc: 1.0000000000 RegLoss: -1.4431612006 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4419317253 Acc: 0.8746898263
# Epoch 397 LR: 0.0000003185
# Epoch 398
# train Loss: 0.0005340990 Acc: 1.0000000000 RegLoss: -1.4418163811 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.3847479828 Acc: 0.8908188586
# Epoch 398 LR: 0.0000003046
# Epoch 399
# train Loss: 0.0007548929 Acc: 1.0000000000 RegLoss: -1.4412378235 ||tau||: stem = 0.5000 layer4.downsample = 0.5160
# val Loss: 0.4205018599 Acc: 0.8821339950
# Epoch 399 LR: 0.0000003000
# Training complete!
# Training time for Seed 10: 1432.05s

# %%
row, col = train_loss.shape

for i, seed in enumerate(seed_lst):
    
    with plt.style.context("ggplot"):
        fig = plt.figure(figsize = (16, 6))
    
        ax0 = fig.add_subplot(1, 2, 1)
        ax0.plot(np.arange(1, num_epochs+1), train_loss[i, :], label = "Training loss", c = "blue")
        ax0.plot(np.arange(1, num_epochs+1), val_loss[i, :], label = "Validation loss", c = "green")
        ax0.set_title("Loss vs Epoch")
        ax0.set_xlabel("Epoch")
        ax0.set_ylabel("Loss")
        ax0.legend()
        ax0.grid(True)
        
        ax1 = fig.add_subplot(1, 2, 2)
        ax1.plot(np.arange(1, num_epochs+1), train_acc[i, :], label = "Training acc", c = "blue")
        ax1.plot(np.arange(1, num_epochs+1), val_acc[i, :], label = "Validation acc", c = "green")
        ax1.set_title("Acc vs Epoch")
        ax1.set_xlabel("Epoch")
        ax1.set_ylabel("Acc")
        ax1.legend()
        ax1.grid(True)

        fig.suptitle(f"Seed {seed}")
        plt.show()

# %%
# seed_lst = [10, 42, 100, 123, 666]
seed_lst = [10]
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
test_acc_lst = []
for i, seed in enumerate(seed_lst):
    print(f"Evaluating Run {i}: Seed {seed}")
    new_model = TIPSResNet18(num_classes=len(train_ds.class_to_idx), pad_type="reflect")
    
    # Load your trained weights
    new_model.load_state_dict(torch.load(
        os.path.join(workspace, f"weights/SSR/Extras/TIPS/SSR_w_noise/rn18_seed{seed}_b16_epochs400.pth"),
        map_location=device
    ))
    
    new_model = new_model.to(device)
    new_model.eval()

    correct = 0
    total = 0
    
    with torch.no_grad():
        for inputs, labels in DataLoader(test_ds, batch_size=32, shuffle=False, num_workers=8, pin_memory = True, persistent_workers=True):
            inputs = inputs.to(device)
            labels = labels.to(device)
    
            outputs, _ = new_model(inputs)
            preds = outputs.argmax(dim=1)
            
            correct += torch.sum(preds == labels).item()
            total += labels.size(0)
    
    test_acc = correct / total
    print(f"Test Accuracy: {100* test_acc:.4f}")
    test_acc_lst.append(test_acc)

test_acc_arr = np.array(test_acc_lst)
print(f"Min: {test_acc_arr.min() * 100:.4f}")
print(f"Max: {test_acc_arr.max() * 100:.4f}")
print(f"Avg, Std: {test_acc_arr.mean() * 100:.4f}, {test_acc_arr.std() * 100:.4f}")
# Out:
# Evaluating Run 0: Seed 10
# Test Accuracy: 92.5788
# Min: 92.5788
# Max: 92.5788
# Avg, Std: 92.5788, 0.0000

# %%
shifted_left_meas_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/real"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), CircularShift(shift_pixels = -5, axis = -1), LogMapping(c = 1000.0), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)
shifted_right_meas_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/real"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), CircularShift(shift_pixels = 15, axis = -1), LogMapping(c = 1000.0), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)
shifted_up_meas_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/real"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), CircularShift(shift_pixels = 10, axis = -2), LogMapping(c = 1000.0), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)
shifted_down_meas_ds = DatasetFolderWithPath(
    os.path.join(data_workspace, "mat_files/real"),
    extensions = (".mat"),
    transform = transforms.Compose([Magnitude(), CircularShift(shift_pixels = -10, axis = -2), LogMapping(c = 1000.0), NumpyToTensor3Channel()]),
    loader = mat_file_loader
)

shifted_left_17 = filter_by_elev(shifted_left_meas_ds, {17})
shifted_right_17 = filter_by_elev(shifted_right_meas_ds, {17})
shifted_up_17 = filter_by_elev(shifted_up_meas_ds, {17})
shifted_down_17 = filter_by_elev(shifted_down_meas_ds, {17})

# %%
# seed_lst = [10, 42, 100, 123, 666]
seed_lst = [10]
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
test_acc_lst = []

for i, seed in enumerate(seed_lst):
    print(f"Evaluating Run {i}: Seed {seed}")
    new_model = TIPSResNet18(num_classes=len(train_ds.class_to_idx), pad_type="reflect")
    
    # Load your trained weights
    new_model.load_state_dict(torch.load(
        os.path.join(workspace, f"weights/SSR/Extras/TIPS/SSR_w_noise/rn18_seed{seed}_b16_epochs400.pth"),
        map_location=device
    ))
    
    new_model = new_model.to(device)
    new_model.eval()
    
    for ds in [test_ds,shifted_left_17, shifted_right_17, shifted_up_17, shifted_down_17]:

        if ds is shifted_left_17:
            print("shifted left by 5 units")
        elif ds is shifted_right_17:
            print("shifted right by 15 units")
        elif ds is shifted_up_17:
            print("shifted up by 10 units")
        elif ds is shifted_down_17:
            print("shifted down by 10 units")
        elif ds is test_ds:
            print("unshifted")
        
        correct = 0
        total = 0
        
        with torch.no_grad():
            for inputs, labels in DataLoader(ds, batch_size=32, shuffle=False, num_workers=8, pin_memory = True, persistent_workers=True):
                inputs = inputs.to(device)
                labels = labels.to(device)
        
                outputs, _ = new_model(inputs)
                preds = outputs.argmax(dim = 1)
        
                correct += torch.sum(preds == labels).item()
                total += labels.size(0)
        
        test_acc = correct / total
        print(f"Test Accuracy: {100 * test_acc:.4f}")
        test_acc_lst.append(test_acc)
    print("\n")
# Out:
# Evaluating Run 0: Seed 10
# unshifted
# Test Accuracy: 92.5788
# shifted left by 5 units
# Test Accuracy: 73.2839
# shifted right by 15 units
# Test Accuracy: 91.6512
# shifted up by 10 units
# Test Accuracy: 62.7087
# shifted down by 10 units
# Test Accuracy: 69.3878

# %%
for ds in [test_ds, shifted_left_17, shifted_right_17, shifted_up_17, shifted_down_17]:

    test_dataloader = DataLoader(ds, batch_size=32, shuffle=False, num_workers=8, pin_memory=True, persistent_workers=True, prefetch_factor=4)

    if ds is shifted_left_17:
        print("shifted left by 5 units")
    elif ds is shifted_right_17:
        print("shifted right by 15 units")
    elif ds is shifted_up_17:
        print("shifted up by 10 units")
    elif ds is shifted_down_17:
        print("shifted down by 10 units")
    elif ds is test_ds:
        print("unshifted")

    seed = 10
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    new_model = TIPSResNet18(num_classes=len(train_ds.class_to_idx), pad_type="reflect")
    
    # Load your trained weights
    new_model.load_state_dict(torch.load(
        os.path.join(workspace, f"weights/SSR/Extras/TIPS/SSR_w_noise/rn18_seed{seed}_b16_epochs400.pth"),
        map_location=device
    ))
    
    new_model = new_model.to(device)
    new_model.eval()
    
    n_test = len(test_ds)
    labels_tensor = torch.zeros(n_test, dtype=torch.long, device=device)
    preds_tensor = torch.zeros(n_test, dtype=torch.long, device=device)
    
    idx = 0
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
    
            outputs, _ = new_model(inputs)
            preds = outputs.argmax(dim=1)
    
            bs = inputs.size(0)
            labels_tensor[idx:idx+bs] = labels
            preds_tensor[idx:idx+bs] = preds
            idx += bs
    
    _labels_all = labels_tensor.cpu().numpy()
    _preds_all = preds_tensor.cpu().numpy()
    
    cm = confusion_matrix(_labels_all, _preds_all)
    cm_cpu = cp.asnumpy(cm)
    disp = ConfusionMatrixDisplay(cm_cpu, display_labels=list(test_ds.class_to_idx.keys()))
    fig, ax = plt.subplots(figsize=(7, 7))
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    ax.tick_params(axis='x', rotation=45)
    plt.show()
    
    cm_norm = confusion_matrix(_labels_all, _preds_all, normalize='true')
    cm_norm_cpu = cp.asnumpy(cm_norm)
    disp = ConfusionMatrixDisplay(cm_norm_cpu, display_labels=list(test_ds.class_to_idx.keys()))
    fig, ax = plt.subplots(figsize=(7, 7))
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    ax.tick_params(axis='x', rotation=45)
    plt.show()
# Out:
# unshifted
# shifted left by 5 units
# shifted right by 15 units
# shifted up by 10 units
# shifted down by 10 units
